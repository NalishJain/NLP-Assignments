# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import json
import gensim.downloader as api
from sklearn.metrics import f1_score
import numpy as np
from gensim.models import KeyedVectors
import pickle
import matplotlib.pyplot as plt

# %%
with open('Json Task1/NER_train.json', 'r') as f:
    task1_train_data = json.load(f)

with open('Json Task1/NER_val.json', 'r') as f:
    task1_val_data = json.load(f)

with open('Json Task1/NER_test.json', 'r') as f:
    task1_test_data = json.load(f)

with open('Json Task2/ATE_train.json', 'r') as f:
    task2_train_data = json.load(f)

with open('Json Task2/ATE_val.json', 'r') as f:
    task2_val_data = json.load(f)

with open('Json Task2/ATE_test.json', 'r') as f:
    task2_test_data = json.load(f)

with open('glove_embedding.pkl', 'rb') as pickle_file:
    glove_embeddings = pickle.load(pickle_file)
    
with open('fast_text_embedding.pkl', 'rb') as pickle_file:
    fast_text_embedding = pickle.load(pickle_file)

with open('word2vec_embeddings.pkl', 'rb') as pickle_file:
    word2vec_embeddings = pickle.load(pickle_file)

bio_mapping_task1 = {'B_ORG': 0, 'I_ORG': 1, 'B_RESPONDENT': 2, 'I_RESPONDENT': 3, 'B_JUDGE': 4, 'I_JUDGE': 5,
               'B_STATUTE': 6, 'I_STATUTE': 7, 'B_OTHER_PERSON': 8, 'I_OTHER_PERSON': 9, 'B_COURT': 10, 'I_COURT': 11,
               'B_GPE': 12, 'I_GPE': 13, 'B_PETITIONER': 14, 'I_PETITIONER': 15, 'B_WITNESS': 16, 'I_WITNESS': 17,
               'B_CASE_NUMBER': 18, 'I_CASE_NUMBER': 19, 'B_PRECEDENT': 20, 'I_PRECEDENT': 21, 'B_DATE': 22, 'I_DATE': 23,
               'B_PROVISION': 24, 'I_PROVISION': 25, 'O': 26}
bio_mapping_task2 = {'O' : 0, 'I' : 1, 'B' : 2}

# %%
def pad_data():
    max_length = 84
    pad_word = 'PAD'

    data = [task1_train_data, task1_val_data, task1_test_data, task2_train_data, task2_val_data, task2_test_data]
    for task_data in data:
        remove_keys = []
        for key in task_data:
            words = task_data[key]['text'].split(' ')
            tags = task_data[key]['labels']
            if(len(words) >= max_length):
                remove_keys.append(key)
                continue
            else:
                for _ in range(len(words), max_length):
                    words.append(pad_word)
                    tags.append('O')   
            task_data[key]['text'] = ' '.join(words)
            task_data[key]['labels'] = tags
        
        for key in remove_keys:
            task_data.pop(key, None)



pad_data()
task1_train_data = {new_key: task1_train_data[old_key] for new_key, (old_key, _) in enumerate(task1_train_data.items())}
task1_val_data = {new_key: task1_val_data[old_key] for new_key, (old_key, _) in enumerate(task1_val_data.items())}
task1_test_data = {new_key: task1_test_data[old_key] for new_key, (old_key, _) in enumerate(task1_test_data.items())}
task2_train_data = {new_key: task2_train_data[old_key] for new_key, (old_key, _) in enumerate(task2_train_data.items())}
task2_val_data = {new_key: task2_val_data[old_key] for new_key, (old_key, _) in enumerate(task2_val_data.items())}
task2_test_data = {new_key: task2_test_data[old_key] for new_key, (old_key, _) in enumerate(task2_test_data.items())}

# %%
class LSTMModel(nn.Module):
    def __init__(self, embedding_dim, output_size):
        super(LSTMModel, self).__init__()
        # self.embedding_layer = nn.Embedding.from_pretrained(pretrained_embedding, freeze=True)
        self.lstm = nn.LSTM(embedding_dim, 32, num_layers=1, batch_first=True)
        self.fc1 = nn.Linear(32, output_size)

    def forward(self, x):
        # x = self.embedding_layer(x)
        out, _ = self.lstm(x)
        out = self.fc1(out)
        return out
    
class Task_data(Dataset):
    def __init__(self, data, bio_index, embedding_type):
        self.data = data
        self.length = len(self.data)
        self.bio_index =  bio_index
        self.embedding_type = embedding_type

    def __len__(self):
        return self.length

    def __getitem__(self, index):
        input_sequence = self.data[index]['text'].split(' ')
        sentence_embeddings = []
        if self.embedding_type == "glove":
            sentence_embeddings = [glove_embeddings.get(word, np.zeros(300, dtype = 'float32')) for word in input_sequence]
        elif self.embedding_type == "word2vec":
            sentence_embeddings = [word2vec_embeddings.get(word, np.zeros(300, dtype = 'float32')) for word in input_sequence]
        elif self.embedding_type == "fast_text":
            sentence_embeddings = [np.array(fast_text_embedding.get(word, np.zeros(300, dtype = 'float32')), dtype = 'float32') for word in input_sequence]

        sentence_embeddings = np.array(sentence_embeddings, dtype='float32')
        output_sequence = self.data[index]['labels']
        output_labels = [self.bio_index[word] for word in output_sequence]

        # output_labels = np.array(output_labels, dtype='float32')
        return torch.tensor(sentence_embeddings), torch.tensor(output_labels)

# %%
def train_model(task, embedding_type, model, optimizer, criterion, device,  num_epochs = 30, batch_size = 256):
    train_dataloader  = None
    val_dataloader  = None
    test_dataloader = None

    if task == 1:
        train_dataloader = DataLoader(Task_data(task1_train_data, bio_mapping_task1, embedding_type), batch_size=batch_size, shuffle=True)
        val_dataloader =  DataLoader(Task_data(task1_val_data, bio_mapping_task1, embedding_type), batch_size=batch_size, shuffle=True)
    elif task == 2:
        train_dataloader = DataLoader(Task_data(task2_train_data, bio_mapping_task2, embedding_type), batch_size=batch_size, shuffle=True)
        val_dataloader =  DataLoader(Task_data(task2_val_data, bio_mapping_task2, embedding_type), batch_size=batch_size, shuffle=True)


    train_losses = []
    val_losses = []
    train_f1_scores = []
    val_f1_scores = []

    # Training loop
    for epoch in range(num_epochs):
        model.train()  # Set the model to training mode
        total_train_loss = 0
        all_train_predictions = []
        all_train_targets = []

        for batch_idx, (inputs, targets) in enumerate(train_dataloader):
            inputs, targets = inputs.to(device), targets.to(device)
            optimizer.zero_grad()
            
            # Forward pass
            outputs = model(inputs)
            
            loss = 0
            # outputs[:, i, :].shape, 
            for i in range(outputs.size(1)):  # Iterate over time steps
                loss += criterion(outputs[:, i, :], targets[:, i])  
                # Apply CrossEntropyLoss at each time step
                # print(outputs[:, i, :].shape, targets[:, i].shape)
            
            loss.backward()
            optimizer.step()

            total_train_loss += loss.item()

            all_train_predictions.extend(outputs.argmax(dim=2).view(-1).cpu().numpy())
            all_train_targets.extend(targets.view(-1).cpu().numpy())


        avg_train_loss = total_train_loss / len(train_dataloader)
        train_losses.append(avg_train_loss)

        train_macro_f1 = f1_score(all_train_targets, all_train_predictions, average='macro')
        train_f1_scores.append(train_macro_f1)
        print(f"Epoch {epoch + 1}, Training Loss: {avg_train_loss}, Training Macro F1-Score: {train_macro_f1}")

        model.eval()  # Set the model to evaluation mode
        total_val_loss = 0
        all_val_predictions = []
        all_val_targets = []

        with torch.no_grad():
            for val_inputs, val_targets in val_dataloader:
                val_inputs, val_targets = val_inputs.to(device), val_targets.to(device)
                val_outputs = model(val_inputs)

                loss = 0
                for i in range(val_outputs.size(1)):  # Iterate over time steps
                    loss += criterion(val_outputs[:, i, :], val_targets[:, i])  

                total_val_loss += loss.item()

                all_val_predictions.extend(val_outputs.argmax(dim=2).view(-1).cpu().numpy())
                all_val_targets.extend(val_targets.view(-1).cpu().numpy())

            avg_val_loss = total_val_loss / len(val_dataloader)
            val_losses.append(avg_val_loss)

            val_macro_f1 = f1_score(all_val_targets, all_val_predictions, average='macro')
            val_f1_scores.append(val_macro_f1)
        print(f"Epoch {epoch + 1},  Validation Loss: {avg_val_loss}, Validation Macro F1-Score: {val_macro_f1}")
    plot_results(train_losses, val_losses, train_f1_scores, val_f1_scores)

    return train_losses, train_f1_scores, val_losses, val_f1_scores

def plot_results(train_losses, val_losses, train_f1_scores, val_f1_scores):
    epochs = range(1, len(train_losses) + 1)

    plt.figure(figsize=(12, 5))

    # Plotting Losses
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label='Training Loss')
    plt.plot(epochs, val_losses, label='Validation Loss')
    plt.title('Training and Validation Losses')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    # Plotting Macro F1-Scores
    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_f1_scores, label='Training Macro F1-Score')
    plt.plot(epochs, val_f1_scores, label='Validation Macro F1-Score')
    plt.title('Training and Validation Macro F1-Scores')
    plt.xlabel('Epochs')
    plt.ylabel('Macro F1-Score')
    plt.legend()

    plt.tight_layout()
    plt.show()

def plot_test_results(test_loss, test_macro_f1):
    plt.figure(figsize=(6, 6))
    labels = ['Test Loss', 'Test Macro F1-Score']
    values = [test_loss, test_macro_f1]

    plt.bar(labels, values, color=['blue', 'green'])
    plt.title('Test Results')
    plt.ylabel('Values')
    plt.show()

def test_model(task, embedding_type, model, criterion, device, batch_size = 1):
    test_dataloader = None
    if task == 1:
        test_dataloader =  DataLoader(Task_data(task1_test_data, bio_mapping_task1, embedding_type), batch_size=batch_size, shuffle=False)

    elif task == 2:
        test_dataloader =  DataLoader(Task_data(task2_test_data, bio_mapping_task2, embedding_type), batch_size=batch_size, shuffle=False)

    total_test_loss = 0
    all_test_predictions = []
    all_test_targets = []

    with torch.no_grad():
        for test_inputs, test_targets in test_dataloader:
            test_inputs, test_targets = test_inputs.to(device), test_targets.to(device)
            test_outputs = model(test_inputs)

            loss = 0
            for i in range(test_outputs.size(1)):  # Iterate over time steps
                loss += criterion(test_outputs[:, i, :], test_targets[:, i])  

            total_test_loss += loss.item()

            all_test_predictions.extend(test_outputs.argmax(dim=2).view(-1).cpu().numpy())
            all_test_targets.extend(test_targets.view(-1).cpu().numpy())

        avg_test_loss = total_test_loss / len(test_dataloader)
        test_macro_f1 = f1_score(all_test_targets, all_test_predictions, average='macro')
    print(f'Test Loss: {avg_test_loss}, Test Macro F1-Score: {test_macro_f1}')

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = LSTMModel(300, 27).to(device) 
optimizer = optim.Adam(model.parameters(), lr=0.01)
criterion = nn.CrossEntropyLoss()

train_losses, train_f1_scores, val_losses, val_f1_scores = train_model(task = 1, embedding_type = "fast_text", model = model, num_epochs = 20, optimizer=optimizer, criterion=criterion, batch_size=128, device=device)
test_model(task = 1, embedding_type = "fast_text", model = model, criterion=criterion, device=device)
torch.save(model, 'trained_models/t1_lstm_fast_text.pt')
# Out:
# Epoch 1, Training Loss: 58.23747641141297, Training Macro F1-Score: 0.0357643118337105
# Epoch 1,  Validation Loss: 29.02975186434659, Validation Macro F1-Score: 0.035966810015755316
# Epoch 2, Training Loss: 23.240094450653576, Training Macro F1-Score: 0.04046479258688199
# Epoch 2,  Validation Loss: 20.95337572964755, Validation Macro F1-Score: 0.04567183511744527
# Epoch 3, Training Loss: 19.042432863204205, Training Macro F1-Score: 0.05640398809274034
# Epoch 3,  Validation Loss: 17.389895265752617, Validation Macro F1-Score: 0.08179384713126281
# Epoch 4, Training Loss: 15.790980198344247, Training Macro F1-Score: 0.10149640949202876
# Epoch 4,  Validation Loss: 14.808638572692871, Validation Macro F1-Score: 0.11214142021382358
# Epoch 5, Training Loss: 13.780310427556273, Training Macro F1-Score: 0.1651599904457773
# Epoch 5,  Validation Loss: 13.178383653814143, Validation Macro F1-Score: 0.21118835128928276
# Epoch 6, Training Loss: 12.348539086638905, Training Macro F1-Score: 0.2438643476932354
# Epoch 6,  Validation Loss: 11.962139476429332, Validation Macro F1-Score: 0.2683682818337887
# Epoch 7, Training Loss: 11.282991487471783, Training Macro F1-Score: 0.30177209876406835
# Epoch 7,  Validation Loss: 11.019640922546387, Validation Macro F1-Score: 0.32453984995792173
# Epoch 8, Training Loss: 10.454427891090267, Training Macro F1-Score: 0.33513073556840556
# Epoch 8,  Validation Loss: 10.444065700877797, Validation Macro F1-Score: 0.3515127628484376
# Epoch 9, Training Loss: 9.855285480374196, Training Macro F1-Score: 0.3567922316807095
# Epoch 9,  Validation Loss: 9.825896783308549, Validation Macro F1-Score: 0.36529193310428176
# Epoch 10, Training Loss: 9.321903267844778, Training Macro F1-Score: 0.37263808920194563
# Epoch 10,  Validation Loss: 9.42392687364058, Validation Macro F1-Score: 0.3786778844990107
# Epoch 11, Training Loss: 8.949192125289166, Training Macro F1-Score: 0.38385147820882004
# Epoch 11,  Validation Loss: 9.247846429998225, Validation Macro F1-Score: 0.3829666481887588
# Epoch 12, Training Loss: 8.638731440559763, Training Macro F1-Score: 0.3956375032727379
# Epoch 12,  Validation Loss: 8.930698004635898, Validation Macro F1-Score: 0.3898014596098917
# Epoch 13, Training Loss: 8.343142564179468, Training Macro F1-Score: 0.4070018926045592
# Epoch 13,  Validation Loss: 8.768183664842086, Validation Macro F1-Score: 0.39869268649955386
# Epoch 14, Training Loss: 8.086936340957392, Training Macro F1-Score: 0.41665827070605405
# Epoch 14,  Validation Loss: 8.50842961398038, Validation Macro F1-Score: 0.4100714538520073
# Epoch 15, Training Loss: 7.9412034300507095, Training Macro F1-Score: 0.4262878460997485
# Epoch 15,  Validation Loss: 8.560399705713445, Validation Macro F1-Score: 0.40931115201031
# Epoch 16, Training Loss: 7.753699912399542, Training Macro F1-Score: 0.43433744595815305
# Epoch 16,  Validation Loss: 8.290068539706143, Validation Macro F1-Score: 0.4179755635053762
# Epoch 17, Training Loss: 7.529077850404333, Training Macro F1-Score: 0.44757110927972327
# Epoch 17,  Validation Loss: 8.182430440729314, Validation Macro F1-Score: 0.4357685191061569
# Epoch 18, Training Loss: 7.450382631333148, Training Macro F1-Score: 0.4539919688886704
# Epoch 18,  Validation Loss: 8.231632839549672, Validation Macro F1-Score: 0.4350027271205016
# Epoch 19, Training Loss: 7.261089895592361, Training Macro F1-Score: 0.46280658069887814
# Epoch 19,  Validation Loss: 8.126401467756791, Validation Macro F1-Score: 0.44331409333506727
# Epoch 20, Training Loss: 7.119364081836138, Training Macro F1-Score: 0.4708345391298059
# Epoch 20,  Validation Loss: 8.030378645116633, Validation Macro F1-Score: 0.4479321454172774
# Test Loss: 8.583206160344139, Test Macro F1-Score: 0.45014480664312484

# %%
model = LSTMModel(300, 27).to(device) 
optimizer = optim.Adam(model.parameters(), lr=0.01)
criterion = nn.CrossEntropyLoss()
train_losses, train_f1_scores, val_losses, val_f1_scores =  train_model(task = 1, embedding_type = "glove", model = model, optimizer=optimizer,criterion=criterion, device=device, batch_size=128)
test_model(task = 1, embedding_type = "glove", model = model, criterion=criterion, device=device)

torch.save(model, 'trained_models/t1_lstm_glove.pt')
# Out:
# Epoch 1, Training Loss: 51.52453297474345, Training Macro F1-Score: 0.045377766274544075
# Epoch 1,  Validation Loss: 21.079380555586383, Validation Macro F1-Score: 0.051936903710354414
# Epoch 2, Training Loss: 17.80933286322922, Training Macro F1-Score: 0.11185574958397211
# Epoch 2,  Validation Loss: 15.427763245322488, Validation Macro F1-Score: 0.1702489866637109
# Epoch 3, Training Loss: 13.740517303591869, Training Macro F1-Score: 0.2579830767037214
# Epoch 3,  Validation Loss: 12.69566839391535, Validation Macro F1-Score: 0.3101321457779682
# Epoch 4, Training Loss: 11.622179172078116, Training Macro F1-Score: 0.3216241941866418
# Epoch 4,  Validation Loss: 11.491522355513139, Validation Macro F1-Score: 0.33560159589294875
# Epoch 5, Training Loss: 10.419817643087418, Training Macro F1-Score: 0.3514836740641599
# Epoch 5,  Validation Loss: 10.653979604894465, Validation Macro F1-Score: 0.3503950186606382
# Epoch 6, Training Loss: 9.530336380004883, Training Macro F1-Score: 0.38046409872146886
# Epoch 6,  Validation Loss: 10.136894486167215, Validation Macro F1-Score: 0.37422784274300996
# Epoch 7, Training Loss: 8.927707078026943, Training Macro F1-Score: 0.40222490261292443
# Epoch 7,  Validation Loss: 9.84969407861883, Validation Macro F1-Score: 0.3919802243568153
# Epoch 8, Training Loss: 8.488725169760283, Training Macro F1-Score: 0.4176853026909967
# Epoch 8,  Validation Loss: 9.573030818592418, Validation Macro F1-Score: 0.3994197191256799
# Epoch 9, Training Loss: 8.066417803529832, Training Macro F1-Score: 0.4305195803972629
# Epoch 9,  Validation Loss: 9.348777640949596, Validation Macro F1-Score: 0.4046861110638353
# Epoch 10, Training Loss: 7.732820573400279, Training Macro F1-Score: 0.44231662422103274
# Epoch 10,  Validation Loss: 9.266303235834295, Validation Macro F1-Score: 0.4173166071310203
# Epoch 11, Training Loss: 7.440935861868937, Training Macro F1-Score: 0.45050500420165895
# Epoch 11,  Validation Loss: 9.23292116685347, Validation Macro F1-Score: 0.41812095070423
# Epoch 12, Training Loss: 7.167861219312324, Training Macro F1-Score: 0.4617630071343247
# Epoch 12,  Validation Loss: 9.095021334561435, Validation Macro F1-Score: 0.4315534748700407
# Epoch 13, Training Loss: 6.930992368791924, Training Macro F1-Score: 0.47160896272286507
# Epoch 13,  Validation Loss: 9.116106380115856, Validation Macro F1-Score: 0.4345119965233482
# Epoch 14, Training Loss: 6.720623203965484, Training Macro F1-Score: 0.48376667282125996
# Epoch 14,  Validation Loss: 9.07966860857877, Validation Macro F1-Score: 0.43542913734185
# Epoch 15, Training Loss: 6.483186917226822, Training Macro F1-Score: 0.4972597973307299
# Epoch 15,  Validation Loss: 9.114381660114635, Validation Macro F1-Score: 0.44100371681704326
# Epoch 16, Training Loss: 6.309759515230773, Training Macro F1-Score: 0.509868435020318
# Epoch 16,  Validation Loss: 9.111564722928135, Validation Macro F1-Score: 0.451101557498887
# Epoch 17, Training Loss: 6.113318779429451, Training Macro F1-Score: 0.5264731882192033
# Epoch 17,  Validation Loss: 9.158269362016158, Validation Macro F1-Score: 0.46089775944732597
# Epoch 18, Training Loss: 5.937373567800053, Training Macro F1-Score: 0.5433306971300006
# Epoch 18,  Validation Loss: 9.289030508561568, Validation Macro F1-Score: 0.46924707283929573
# Epoch 19, Training Loss: 5.802103175491583, Training Macro F1-Score: 0.553641033401292
# Epoch 19,  Validation Loss: 9.148010904138738, Validation Macro F1-Score: 0.4731698813079821
# Epoch 20, Training Loss: 5.75339162545126, Training Macro F1-Score: 0.5636427498607895
# Epoch 20,  Validation Loss: 9.507788788188588, Validation Macro F1-Score: 0.45054679010300375
# Epoch 21, Training Loss: 5.677931715230473, Training Macro F1-Score: 0.574899373414193
# Epoch 21,  Validation Loss: 9.377962806008078, Validation Macro F1-Score: 0.4812443596545202
# Epoch 22, Training Loss: 5.484910198899566, Training Macro F1-Score: 0.5909658874336056
# Epoch 22,  Validation Loss: 9.392356048930775, Validation Macro F1-Score: 0.4793724617658934
# Epoch 23, Training Loss: 5.26201159836816, Training Macro F1-Score: 0.6060627448567307
# Epoch 23,  Validation Loss: 9.611482533541592, Validation Macro F1-Score: 0.47640462915852017
# Epoch 24, Training Loss: 5.132821325395928, Training Macro F1-Score: 0.6155067288020605
# Epoch 24,  Validation Loss: 9.552809975363992, Validation Macro F1-Score: 0.4890422806721669
# Epoch 25, Training Loss: 5.024623714509557, Training Macro F1-Score: 0.6335844712550371
# Epoch 25,  Validation Loss: 9.652360742742365, Validation Macro F1-Score: 0.49296377920848805
# Epoch 26, Training Loss: 4.903519794589183, Training Macro F1-Score: 0.637838837637288
# Epoch 26,  Validation Loss: 9.768243182789195, Validation Macro F1-Score: 0.48907995927088926
# Epoch 27, Training Loss: 4.7979806642063325, Training Macro F1-Score: 0.6503924528762659
# Epoch 27,  Validation Loss: 9.833191828294234, Validation Macro F1-Score: 0.498560094920149
# Epoch 28, Training Loss: 4.694921481804769, Training Macro F1-Score: 0.6547413536835932
# Epoch 28,  Validation Loss: 9.929444833235307, Validation Macro F1-Score: 0.4999235222589525
# Epoch 29, Training Loss: 4.587727761659466, Training Macro F1-Score: 0.6681717622374713
# Epoch 29,  Validation Loss: 10.055111408233643, Validation Macro F1-Score: 0.495633927161983
# Epoch 30, Training Loss: 4.519530964679405, Training Macro F1-Score: 0.6703429668481106
# Epoch 30,  Validation Loss: 10.2846341566606, Validation Macro F1-Score: 0.49599851499851094
# Test Loss: 11.591764899088785, Test Macro F1-Score: 0.48691259136665765

# %%
model = LSTMModel(300, 27).to(device) 
optimizer = optim.Adam(model.parameters(), lr=0.01)
criterion = nn.CrossEntropyLoss()
train_losses, train_f1_scores, val_losses, val_f1_scores =  train_model(task = 1, embedding_type = "word2vec", model = model, optimizer=optimizer, criterion=criterion, device=device, batch_size=128)
test_model(task = 1, embedding_type = "word2vec", model = model, criterion=criterion, device=device)

torch.save(model, 'trained_models/t1_lstm_word2vec.pt')
# Out:
# Epoch 1, Training Loss: 55.4253038187496, Training Macro F1-Score: 0.03645916749535785
# Epoch 1,  Validation Loss: 27.73179175636985, Validation Macro F1-Score: 0.03592527401765281
# Epoch 2, Training Loss: 23.56067726260326, Training Macro F1-Score: 0.06786860179844224
# Epoch 2,  Validation Loss: 19.62944360212846, Validation Macro F1-Score: 0.09231323520535864
# Epoch 3, Training Loss: 17.747463929848593, Training Macro F1-Score: 0.12702391023689494
# Epoch 3,  Validation Loss: 16.307565342296254, Validation Macro F1-Score: 0.1687164008078127
# Epoch 4, Training Loss: 15.162377373116914, Training Macro F1-Score: 0.2017867208613589
# Epoch 4,  Validation Loss: 14.562291838906027, Validation Macro F1-Score: 0.21913624701436948
# Epoch 5, Training Loss: 13.619871530376496, Training Macro F1-Score: 0.2528280701864845
# Epoch 5,  Validation Loss: 13.36818486993963, Validation Macro F1-Score: 0.26673875183921647
# Epoch 6, Training Loss: 12.512047329887015, Training Macro F1-Score: 0.2882630395696718
# Epoch 6,  Validation Loss: 12.615826433355158, Validation Macro F1-Score: 0.30227702610416357
# Epoch 7, Training Loss: 11.804425270830999, Training Macro F1-Score: 0.31156261528896145
# Epoch 7,  Validation Loss: 12.121315782720393, Validation Macro F1-Score: 0.3095374255701149
# Epoch 8, Training Loss: 11.235457733029225, Training Macro F1-Score: 0.3285328518330975
# Epoch 8,  Validation Loss: 11.794038079001687, Validation Macro F1-Score: 0.32354876937601795
# Epoch 9, Training Loss: 10.835293707300405, Training Macro F1-Score: 0.3433098520483092
# Epoch 9,  Validation Loss: 11.619706067171963, Validation Macro F1-Score: 0.33729830359051677
# Epoch 10, Training Loss: 10.472090674228356, Training Macro F1-Score: 0.35803974444613534
# Epoch 10,  Validation Loss: 11.4949951171875, Validation Macro F1-Score: 0.3508198210111884
# Epoch 11, Training Loss: 10.153375672512366, Training Macro F1-Score: 0.36995376597432283
# Epoch 11,  Validation Loss: 11.27097580649636, Validation Macro F1-Score: 0.3555177503725735
# Epoch 12, Training Loss: 9.844564242441146, Training Macro F1-Score: 0.38136493630095036
# Epoch 12,  Validation Loss: 11.21457628770308, Validation Macro F1-Score: 0.3614495075107604
# Epoch 13, Training Loss: 9.608427587102671, Training Macro F1-Score: 0.3856761781471335
# Epoch 13,  Validation Loss: 11.124343005093662, Validation Macro F1-Score: 0.36716536063010885
# Epoch 14, Training Loss: 9.358215105338175, Training Macro F1-Score: 0.39378261426086153
# Epoch 14,  Validation Loss: 11.000629164955832, Validation Macro F1-Score: 0.37650935055009255
# Epoch 15, Training Loss: 9.125220079891017, Training Macro F1-Score: 0.40113868811331954
# Epoch 15,  Validation Loss: 10.983437798239969, Validation Macro F1-Score: 0.37765833576481994
# Epoch 16, Training Loss: 8.961066003705634, Training Macro F1-Score: 0.4084454017512534
# Epoch 16,  Validation Loss: 11.119985667142002, Validation Macro F1-Score: 0.3773725232923332
# Epoch 17, Training Loss: 8.77358986119755, Training Macro F1-Score: 0.41443291883506006
# Epoch 17,  Validation Loss: 10.99197985909202, Validation Macro F1-Score: 0.38540007992923764
# Epoch 18, Training Loss: 8.555775095204838, Training Macro F1-Score: 0.4280987169075894
# Epoch 18,  Validation Loss: 10.7989613793113, Validation Macro F1-Score: 0.39302224030350114
# Epoch 19, Training Loss: 8.359342512537221, Training Macro F1-Score: 0.434161369452439
# Epoch 19,  Validation Loss: 10.857442855834961, Validation Macro F1-Score: 0.3966183759331275
# Epoch 20, Training Loss: 8.223315293671655, Training Macro F1-Score: 0.4436379518761547
# Epoch 20,  Validation Loss: 11.022240552035244, Validation Macro F1-Score: 0.40050608602209053
# Epoch 21, Training Loss: 8.139815111629298, Training Macro F1-Score: 0.4511596599912032
# Epoch 21,  Validation Loss: 10.933055704290217, Validation Macro F1-Score: 0.4137589912602174
# Epoch 22, Training Loss: 7.967321153546943, Training Macro F1-Score: 0.46167104211530685
# Epoch 22,  Validation Loss: 11.040405880321156, Validation Macro F1-Score: 0.41578911858452383
# Epoch 23, Training Loss: 7.824594857262784, Training Macro F1-Score: 0.4713488335220519
# Epoch 23,  Validation Loss: 10.931496620178223, Validation Macro F1-Score: 0.41462192814885895
# Epoch 24, Training Loss: 8.053026527654929, Training Macro F1-Score: 0.47142641812257485
# Epoch 24,  Validation Loss: 10.908764318986373, Validation Macro F1-Score: 0.4200119046880847
# Epoch 25, Training Loss: 7.652341834834365, Training Macro F1-Score: 0.48839702683961334
# Epoch 25,  Validation Loss: 10.991277694702148, Validation Macro F1-Score: 0.4174192902172962
# Epoch 26, Training Loss: 7.445811365471512, Training Macro F1-Score: 0.49521176123155447
# Epoch 26,  Validation Loss: 10.956142685630105, Validation Macro F1-Score: 0.4273723138223144
# Epoch 27, Training Loss: 7.318165403897645, Training Macro F1-Score: 0.5063345081069345
# Epoch 27,  Validation Loss: 11.042693918401545, Validation Macro F1-Score: 0.43816807101800187
# Epoch 28, Training Loss: 7.253252474988093, Training Macro F1-Score: 0.515180927512517
# Epoch 28,  Validation Loss: 11.064545371315695, Validation Macro F1-Score: 0.4329916047751488
# Epoch 29, Training Loss: 7.12286940559012, Training Macro F1-Score: 0.5195265702716213
# Epoch 29,  Validation Loss: 11.06130227175626, Validation Macro F1-Score: 0.43867852088480014
# Epoch 30, Training Loss: 6.970772063145872, Training Macro F1-Score: 0.5331803473107389
# Epoch 30,  Validation Loss: 11.26825020530007, Validation Macro F1-Score: 0.43836849824850016
# Test Loss: 12.965984447801464, Test Macro F1-Score: 0.44395642899718474

# %%
model = LSTMModel(300, 3).to(device) 
optimizer = optim.Adam(model.parameters(), lr=0.01)
criterion = nn.CrossEntropyLoss()
train_losses, train_f1_scores, val_losses, val_f1_scores = train_model(task = 2, embedding_type = "fast_text", model = model, optimizer=optimizer, criterion=criterion, device=device, batch_size=256)

test_model(task = 2, embedding_type = "fast_text", model = model, criterion=criterion, device=device)
torch.save(model, 'trained_models/t2_lstm_fast_text.pt')
# Out:
# Epoch 1, Training Loss: 80.54133415222168, Training Macro F1-Score: 0.2870999990397189
# Epoch 1,  Validation Loss: 46.66402053833008, Validation Macro F1-Score: 0.329410039232941
# Epoch 2, Training Loss: 25.28185272216797, Training Macro F1-Score: 0.32919834423063704
# Epoch 2,  Validation Loss: 10.424830436706543, Validation Macro F1-Score: 0.329410039232941
# Epoch 3, Training Loss: 11.045010089874268, Training Macro F1-Score: 0.32919834423063704
# Epoch 3,  Validation Loss: 11.287010192871094, Validation Macro F1-Score: 0.329410039232941
# Epoch 4, Training Loss: 12.429161787033081, Training Macro F1-Score: 0.32919834423063704
# Epoch 4,  Validation Loss: 12.255016326904297, Validation Macro F1-Score: 0.329410039232941
# Epoch 5, Training Loss: 12.959129810333252, Training Macro F1-Score: 0.32919834423063704
# Epoch 5,  Validation Loss: 12.163297653198242, Validation Macro F1-Score: 0.329410039232941
# Epoch 6, Training Loss: 12.557616472244263, Training Macro F1-Score: 0.32919834423063704
# Epoch 6,  Validation Loss: 11.393074035644531, Validation Macro F1-Score: 0.329410039232941
# Epoch 7, Training Loss: 11.66239309310913, Training Macro F1-Score: 0.32919834423063704
# Epoch 7,  Validation Loss: 10.419984817504883, Validation Macro F1-Score: 0.329410039232941
# Epoch 8, Training Loss: 10.624038457870483, Training Macro F1-Score: 0.32919834423063704
# Epoch 8,  Validation Loss: 9.771429061889648, Validation Macro F1-Score: 0.329410039232941
# Epoch 9, Training Loss: 10.215249061584473, Training Macro F1-Score: 0.32919834423063704
# Epoch 9,  Validation Loss: 9.737890243530273, Validation Macro F1-Score: 0.329410039232941
# Epoch 10, Training Loss: 10.28974962234497, Training Macro F1-Score: 0.32919834423063704
# Epoch 10,  Validation Loss: 9.69802474975586, Validation Macro F1-Score: 0.329410039232941
# Epoch 11, Training Loss: 10.018600463867188, Training Macro F1-Score: 0.32919834423063704
# Epoch 11,  Validation Loss: 9.359626770019531, Validation Macro F1-Score: 0.329410039232941
# Epoch 12, Training Loss: 9.629192352294922, Training Macro F1-Score: 0.32919834423063704
# Epoch 12,  Validation Loss: 9.018528938293457, Validation Macro F1-Score: 0.329410039232941
# Epoch 13, Training Loss: 9.301095008850098, Training Macro F1-Score: 0.32919834423063704
# Epoch 13,  Validation Loss: 8.73979377746582, Validation Macro F1-Score: 0.329410039232941
# Epoch 14, Training Loss: 8.981656074523926, Training Macro F1-Score: 0.32919834423063704
# Epoch 14,  Validation Loss: 8.423977851867676, Validation Macro F1-Score: 0.329410039232941
# Epoch 15, Training Loss: 8.549223065376282, Training Macro F1-Score: 0.32919834423063704
# Epoch 15,  Validation Loss: 8.056903839111328, Validation Macro F1-Score: 0.329410039232941
# Epoch 16, Training Loss: 8.234516382217407, Training Macro F1-Score: 0.32919834423063704
# Epoch 16,  Validation Loss: 7.731420516967773, Validation Macro F1-Score: 0.329410039232941
# Epoch 17, Training Loss: 7.858820796012878, Training Macro F1-Score: 0.32919834423063704
# Epoch 17,  Validation Loss: 7.407993793487549, Validation Macro F1-Score: 0.329410039232941
# Epoch 18, Training Loss: 7.522460460662842, Training Macro F1-Score: 0.32919834423063704
# Epoch 18,  Validation Loss: 7.065649032592773, Validation Macro F1-Score: 0.329410039232941
# Epoch 19, Training Loss: 7.176734089851379, Training Macro F1-Score: 0.32919834423063704
# Epoch 19,  Validation Loss: 6.774507522583008, Validation Macro F1-Score: 0.3316668719351718
# Epoch 20, Training Loss: 6.837144732475281, Training Macro F1-Score: 0.33127905023712445
# Epoch 20,  Validation Loss: 6.487454414367676, Validation Macro F1-Score: 0.33165016501650163
# Epoch 21, Training Loss: 6.653921723365784, Training Macro F1-Score: 0.3338171488134299
# Epoch 21,  Validation Loss: 6.229665279388428, Validation Macro F1-Score: 0.3338134780233673
# Epoch 22, Training Loss: 6.359219551086426, Training Macro F1-Score: 0.33678057295413066
# Epoch 22,  Validation Loss: 5.996109962463379, Validation Macro F1-Score: 0.33374278806083896
# Epoch 23, Training Loss: 6.147991895675659, Training Macro F1-Score: 0.33922691221815593
# Epoch 23,  Validation Loss: 5.798587799072266, Validation Macro F1-Score: 0.33795532078793883
# Epoch 24, Training Loss: 6.046168804168701, Training Macro F1-Score: 0.3416077586725994
# Epoch 24,  Validation Loss: 5.626302719116211, Validation Macro F1-Score: 0.3379187352015464
# Epoch 25, Training Loss: 5.742950916290283, Training Macro F1-Score: 0.3443763788209046
# Epoch 25,  Validation Loss: 5.477369785308838, Validation Macro F1-Score: 0.34195591353318594
# Epoch 26, Training Loss: 5.645378589630127, Training Macro F1-Score: 0.3478286152694554
# Epoch 26,  Validation Loss: 5.335724353790283, Validation Macro F1-Score: 0.34784840442506654
# Epoch 27, Training Loss: 5.524046421051025, Training Macro F1-Score: 0.34929784496468347
# Epoch 27,  Validation Loss: 5.204272747039795, Validation Macro F1-Score: 0.3573674641246623
# Epoch 28, Training Loss: 5.413721323013306, Training Macro F1-Score: 0.35292958843846733
# Epoch 28,  Validation Loss: 5.075738906860352, Validation Macro F1-Score: 0.3660088652314823
# Epoch 29, Training Loss: 5.243855953216553, Training Macro F1-Score: 0.3606597309157669
# Epoch 29,  Validation Loss: 4.951613426208496, Validation Macro F1-Score: 0.37584634220997853
# Epoch 30, Training Loss: 5.101899147033691, Training Macro F1-Score: 0.37488643320350795
# Epoch 30,  Validation Loss: 4.82913064956665, Validation Macro F1-Score: 0.3866079570078195
# Test Loss: 5.099730147094261, Test Macro F1-Score: 0.39782553143656035

# %%
model = LSTMModel(300, 3).to(device) 
optimizer = optim.Adam(model.parameters(), lr=0.01)
criterion = nn.CrossEntropyLoss()
train_losses, train_f1_scores, val_losses, val_f1_scores = train_model(task = 2, embedding_type = "glove", model = model, optimizer=optimizer, criterion=criterion, device=device)
test_model(task = 2, embedding_type = "glove", model = model, criterion=criterion, device=device)
torch.save(model, 'trained_models/t2_lstm_glove.pt')
# Out:
# Epoch 1, Training Loss: 77.82538986206055, Training Macro F1-Score: 0.3074038539857758
# Epoch 1,  Validation Loss: 42.84417724609375, Validation Macro F1-Score: 0.33166376707888684
# Epoch 2, Training Loss: 22.166632413864136, Training Macro F1-Score: 0.3307542605363429
# Epoch 2,  Validation Loss: 9.892746925354004, Validation Macro F1-Score: 0.329410039232941
# Epoch 3, Training Loss: 10.68202018737793, Training Macro F1-Score: 0.3307634683985854
# Epoch 3,  Validation Loss: 10.054678916931152, Validation Macro F1-Score: 0.329410039232941
# Epoch 4, Training Loss: 10.286328077316284, Training Macro F1-Score: 0.3307634683985854
# Epoch 4,  Validation Loss: 8.434687614440918, Validation Macro F1-Score: 0.329410039232941
# Epoch 5, Training Loss: 8.230817675590515, Training Macro F1-Score: 0.3307634683985854
# Epoch 5,  Validation Loss: 6.60007905960083, Validation Macro F1-Score: 0.329410039232941
# Epoch 6, Training Loss: 6.604649305343628, Training Macro F1-Score: 0.3307634683985854
# Epoch 6,  Validation Loss: 5.627218246459961, Validation Macro F1-Score: 0.329410039232941
# Epoch 7, Training Loss: 5.86728036403656, Training Macro F1-Score: 0.3307644479269495
# Epoch 7,  Validation Loss: 5.41690731048584, Validation Macro F1-Score: 0.329410039232941
# Epoch 8, Training Loss: 5.69826602935791, Training Macro F1-Score: 0.3307676192319719
# Epoch 8,  Validation Loss: 5.442092418670654, Validation Macro F1-Score: 0.329410039232941
# Epoch 9, Training Loss: 5.640492081642151, Training Macro F1-Score: 0.3323163161021654
# Epoch 9,  Validation Loss: 5.279468536376953, Validation Macro F1-Score: 0.329410039232941
# Epoch 10, Training Loss: 5.417253375053406, Training Macro F1-Score: 0.3323116732456664
# Epoch 10,  Validation Loss: 5.0419793128967285, Validation Macro F1-Score: 0.32941909816755127
# Epoch 11, Training Loss: 5.123781800270081, Training Macro F1-Score: 0.33332885402141466
# Epoch 11,  Validation Loss: 4.867223262786865, Validation Macro F1-Score: 0.3338850177373252
# Epoch 12, Training Loss: 5.004526138305664, Training Macro F1-Score: 0.3363447009318459
# Epoch 12,  Validation Loss: 4.748590469360352, Validation Macro F1-Score: 0.3486631143493129
# Epoch 13, Training Loss: 4.857735872268677, Training Macro F1-Score: 0.3720481910463253
# Epoch 13,  Validation Loss: 4.630207538604736, Validation Macro F1-Score: 0.394131943756631
# Epoch 14, Training Loss: 4.7285778522491455, Training Macro F1-Score: 0.43087607958064417
# Epoch 14,  Validation Loss: 4.530714988708496, Validation Macro F1-Score: 0.4439499370800048
# Epoch 15, Training Loss: 4.544790983200073, Training Macro F1-Score: 0.4685448884097068
# Epoch 15,  Validation Loss: 4.448241233825684, Validation Macro F1-Score: 0.46489861835263774
# Epoch 16, Training Loss: 4.45722222328186, Training Macro F1-Score: 0.4841795787675975
# Epoch 16,  Validation Loss: 4.369124412536621, Validation Macro F1-Score: 0.48572594644714395
# Epoch 17, Training Loss: 4.325973749160767, Training Macro F1-Score: 0.4951689788824687
# Epoch 17,  Validation Loss: 4.288998603820801, Validation Macro F1-Score: 0.4916804848225505
# Epoch 18, Training Loss: 4.2119739055633545, Training Macro F1-Score: 0.5006975332905427
# Epoch 18,  Validation Loss: 4.197801113128662, Validation Macro F1-Score: 0.5029093540571479
# Epoch 19, Training Loss: 4.0807942152023315, Training Macro F1-Score: 0.5114534592111267
# Epoch 19,  Validation Loss: 4.126461505889893, Validation Macro F1-Score: 0.5031451509396679
# Epoch 20, Training Loss: 3.981174409389496, Training Macro F1-Score: 0.517210952019593
# Epoch 20,  Validation Loss: 4.066343307495117, Validation Macro F1-Score: 0.507523851481975
# Epoch 21, Training Loss: 3.9420079588890076, Training Macro F1-Score: 0.524956642507944
# Epoch 21,  Validation Loss: 3.9974915981292725, Validation Macro F1-Score: 0.5095356020867533
# Epoch 22, Training Loss: 3.778174936771393, Training Macro F1-Score: 0.5333504428401855
# Epoch 22,  Validation Loss: 3.956136703491211, Validation Macro F1-Score: 0.5133216585585466
# Epoch 23, Training Loss: 3.713281512260437, Training Macro F1-Score: 0.5440685797815448
# Epoch 23,  Validation Loss: 3.898285150527954, Validation Macro F1-Score: 0.5364765001657388
# Epoch 24, Training Loss: 3.5896589756011963, Training Macro F1-Score: 0.5558721036291224
# Epoch 24,  Validation Loss: 3.8527071475982666, Validation Macro F1-Score: 0.5538121381480605
# Epoch 25, Training Loss: 3.5299131870269775, Training Macro F1-Score: 0.5792052496584611
# Epoch 25,  Validation Loss: 3.846024990081787, Validation Macro F1-Score: 0.5736808668689051
# Epoch 26, Training Loss: 3.432338297367096, Training Macro F1-Score: 0.592685628482018
# Epoch 26,  Validation Loss: 3.770082473754883, Validation Macro F1-Score: 0.5764211342645086
# Epoch 27, Training Loss: 3.3255487084388733, Training Macro F1-Score: 0.6096308722838645
# Epoch 27,  Validation Loss: 3.787090301513672, Validation Macro F1-Score: 0.5758563149612854
# Epoch 28, Training Loss: 3.2890183329582214, Training Macro F1-Score: 0.6163595120169205
# Epoch 28,  Validation Loss: 3.720350503921509, Validation Macro F1-Score: 0.5871599300532683
# Epoch 29, Training Loss: 3.2023584246635437, Training Macro F1-Score: 0.6178464279607271
# Epoch 29,  Validation Loss: 3.7165422439575195, Validation Macro F1-Score: 0.588846305847252
# Epoch 30, Training Loss: 3.137885868549347, Training Macro F1-Score: 0.6316279855629446
# Epoch 30,  Validation Loss: 3.6633782386779785, Validation Macro F1-Score: 0.5936685588982877
# Test Loss: 3.83084511884102, Test Macro F1-Score: 0.5835704061603947

# %%
model = LSTMModel(300, 3).to(device) 
optimizer = optim.Adam(model.parameters(), lr=0.01)
criterion = nn.CrossEntropyLoss()

train_losses, train_f1_scores, val_losses, val_f1_scores = train_model(task = 2, embedding_type = "word2vec", model = model, num_epochs=30,optimizer=optimizer, criterion=criterion, device=device)
test_model(task = 2, embedding_type = "word2vec", model = model, criterion=criterion, device=device)
torch.save(model, 'trained_models/t2_lstm_word2vec.pt')
# Out:
# Epoch 1, Training Loss: 76.52991199493408, Training Macro F1-Score: 0.3718526063025656
# Epoch 1,  Validation Loss: 48.79016876220703, Validation Macro F1-Score: 0.329410039232941
# Epoch 2, Training Loss: 28.510682821273804, Training Macro F1-Score: 0.32919834423063704
# Epoch 2,  Validation Loss: 11.078325271606445, Validation Macro F1-Score: 0.329410039232941
# Epoch 3, Training Loss: 11.088879823684692, Training Macro F1-Score: 0.32919834423063704
# Epoch 3,  Validation Loss: 10.762554168701172, Validation Macro F1-Score: 0.329410039232941
# Epoch 4, Training Loss: 11.705321788787842, Training Macro F1-Score: 0.32919834423063704
# Epoch 4,  Validation Loss: 10.973822593688965, Validation Macro F1-Score: 0.329410039232941
# Epoch 5, Training Loss: 11.481383323669434, Training Macro F1-Score: 0.32919834423063704
# Epoch 5,  Validation Loss: 9.802916526794434, Validation Macro F1-Score: 0.329410039232941
# Epoch 6, Training Loss: 9.931181192398071, Training Macro F1-Score: 0.32919834423063704
# Epoch 6,  Validation Loss: 8.136707305908203, Validation Macro F1-Score: 0.329410039232941
# Epoch 7, Training Loss: 8.36070990562439, Training Macro F1-Score: 0.32919834423063704
# Epoch 7,  Validation Loss: 6.903943061828613, Validation Macro F1-Score: 0.329410039232941
# Epoch 8, Training Loss: 7.25282895565033, Training Macro F1-Score: 0.32919834423063704
# Epoch 8,  Validation Loss: 6.361689567565918, Validation Macro F1-Score: 0.329410039232941
# Epoch 9, Training Loss: 6.8020548820495605, Training Macro F1-Score: 0.32919834423063704
# Epoch 9,  Validation Loss: 6.175762176513672, Validation Macro F1-Score: 0.329410039232941
# Epoch 10, Training Loss: 6.447099208831787, Training Macro F1-Score: 0.32919834423063704
# Epoch 10,  Validation Loss: 5.930881977081299, Validation Macro F1-Score: 0.329410039232941
# Epoch 11, Training Loss: 6.197434425354004, Training Macro F1-Score: 0.32919834423063704
# Epoch 11,  Validation Loss: 5.587499141693115, Validation Macro F1-Score: 0.329410039232941
# Epoch 12, Training Loss: 5.8249194622039795, Training Macro F1-Score: 0.32919834423063704
# Epoch 12,  Validation Loss: 5.304272651672363, Validation Macro F1-Score: 0.329410039232941
# Epoch 13, Training Loss: 5.582375645637512, Training Macro F1-Score: 0.32919834423063704
# Epoch 13,  Validation Loss: 5.122725486755371, Validation Macro F1-Score: 0.329410039232941
# Epoch 14, Training Loss: 5.373129487037659, Training Macro F1-Score: 0.32919834423063704
# Epoch 14,  Validation Loss: 5.000549793243408, Validation Macro F1-Score: 0.329410039232941
# Epoch 15, Training Loss: 5.305662751197815, Training Macro F1-Score: 0.32919834423063704
# Epoch 15,  Validation Loss: 4.9016876220703125, Validation Macro F1-Score: 0.329410039232941
# Epoch 16, Training Loss: 5.173191666603088, Training Macro F1-Score: 0.32919834423063704
# Epoch 16,  Validation Loss: 4.811317443847656, Validation Macro F1-Score: 0.329410039232941
# Epoch 17, Training Loss: 5.115204334259033, Training Macro F1-Score: 0.32919834423063704
# Epoch 17,  Validation Loss: 4.726339340209961, Validation Macro F1-Score: 0.329410039232941
# Epoch 18, Training Loss: 5.044659972190857, Training Macro F1-Score: 0.32919834423063704
# Epoch 18,  Validation Loss: 4.6482415199279785, Validation Macro F1-Score: 0.329410039232941
# Epoch 19, Training Loss: 4.951785564422607, Training Macro F1-Score: 0.3297179047070423
# Epoch 19,  Validation Loss: 4.575945854187012, Validation Macro F1-Score: 0.329400764513379
# Epoch 20, Training Loss: 4.843834638595581, Training Macro F1-Score: 0.3434805739563063
# Epoch 20,  Validation Loss: 4.509403228759766, Validation Macro F1-Score: 0.3468931685197231
# Epoch 21, Training Loss: 4.758758068084717, Training Macro F1-Score: 0.3590362338602821
# Epoch 21,  Validation Loss: 4.445519924163818, Validation Macro F1-Score: 0.35112712258398876
# Epoch 22, Training Loss: 4.665453553199768, Training Macro F1-Score: 0.3594620405379036
# Epoch 22,  Validation Loss: 4.382009983062744, Validation Macro F1-Score: 0.35302263306555154
# Epoch 23, Training Loss: 4.629066705703735, Training Macro F1-Score: 0.3630885405050534
# Epoch 23,  Validation Loss: 4.3159403800964355, Validation Macro F1-Score: 0.35508653089512626
# Epoch 24, Training Loss: 4.533686876296997, Training Macro F1-Score: 0.37272397711466954
# Epoch 24,  Validation Loss: 4.249333381652832, Validation Macro F1-Score: 0.39493401295228175
# Epoch 25, Training Loss: 4.4789509773254395, Training Macro F1-Score: 0.4052595057065098
# Epoch 25,  Validation Loss: 4.182730197906494, Validation Macro F1-Score: 0.4336204021654337
# Epoch 26, Training Loss: 4.354398846626282, Training Macro F1-Score: 0.44814683741258454
# Epoch 26,  Validation Loss: 4.1110992431640625, Validation Macro F1-Score: 0.49541269928801634
# Epoch 27, Training Loss: 4.267502784729004, Training Macro F1-Score: 0.5156274862499743
# Epoch 27,  Validation Loss: 4.040904521942139, Validation Macro F1-Score: 0.5491013719283006
# Epoch 28, Training Loss: 4.073644995689392, Training Macro F1-Score: 0.5849757140615058
# Epoch 28,  Validation Loss: 3.95352840423584, Validation Macro F1-Score: 0.6083091586518125
# Epoch 29, Training Loss: 4.043868005275726, Training Macro F1-Score: 0.6419430376799267
# Epoch 29,  Validation Loss: 3.8698837757110596, Validation Macro F1-Score: 0.632410167205119
# Epoch 30, Training Loss: 3.9434242248535156, Training Macro F1-Score: 0.66766778146666
# Epoch 30,  Validation Loss: 3.786341428756714, Validation Macro F1-Score: 0.6526320990469624
# Test Loss: 4.085268241058036, Test Macro F1-Score: 0.6393910482986204
