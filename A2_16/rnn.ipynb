# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import json
import gensim.downloader as api
from sklearn.metrics import f1_score
import numpy as np
from gensim.models import KeyedVectors
import pickle
import matplotlib.pyplot as plt

# %%
with open('Json Task1/NER_train.json', 'r') as f:
    task1_train_data = json.load(f)

with open('Json Task1/NER_val.json', 'r') as f:
    task1_val_data = json.load(f)

with open('Json Task1/NER_test.json', 'r') as f:
    task1_test_data = json.load(f)

with open('Json Task2/ATE_train.json', 'r') as f:
    task2_train_data = json.load(f)

with open('Json Task2/ATE_val.json', 'r') as f:
    task2_val_data = json.load(f)

with open('Json Task2/ATE_test.json', 'r') as f:
    task2_test_data = json.load(f)

with open('glove_embedding.pkl', 'rb') as pickle_file:
    glove_embeddings = pickle.load(pickle_file)
    
with open('fast_text_embedding.pkl', 'rb') as pickle_file:
    fast_text_embedding = pickle.load(pickle_file)

with open('word2vec_embeddings.pkl', 'rb') as pickle_file:
    word2vec_embeddings = pickle.load(pickle_file)

bio_mapping_task1 = {'B_ORG': 0, 'I_ORG': 1, 'B_RESPONDENT': 2, 'I_RESPONDENT': 3, 'B_JUDGE': 4, 'I_JUDGE': 5,
               'B_STATUTE': 6, 'I_STATUTE': 7, 'B_OTHER_PERSON': 8, 'I_OTHER_PERSON': 9, 'B_COURT': 10, 'I_COURT': 11,
               'B_GPE': 12, 'I_GPE': 13, 'B_PETITIONER': 14, 'I_PETITIONER': 15, 'B_WITNESS': 16, 'I_WITNESS': 17,
               'B_CASE_NUMBER': 18, 'I_CASE_NUMBER': 19, 'B_PRECEDENT': 20, 'I_PRECEDENT': 21, 'B_DATE': 22, 'I_DATE': 23,
               'B_PROVISION': 24, 'I_PROVISION': 25, 'O': 26}
bio_mapping_task2 = {'O' : 0, 'I' : 1, 'B' : 2}

# %%
def pad_data():
    max_length = 84
    pad_word = 'PAD'

    data = [task1_train_data, task1_val_data, task1_test_data, task2_train_data, task2_val_data, task2_test_data]
    for task_data in data:
        remove_keys = []
        for key in task_data:
            words = task_data[key]['text'].split(' ')
            tags = task_data[key]['labels']
            if(len(words) >= max_length):
                remove_keys.append(key)
                continue
            else:
                for _ in range(len(words), max_length):
                    words.append(pad_word)
                    tags.append('O')   
            task_data[key]['text'] = ' '.join(words)
            task_data[key]['labels'] = tags
        
        for key in remove_keys:
            task_data.pop(key, None)



pad_data()
task1_train_data = {new_key: task1_train_data[old_key] for new_key, (old_key, _) in enumerate(task1_train_data.items())}
task1_val_data = {new_key: task1_val_data[old_key] for new_key, (old_key, _) in enumerate(task1_val_data.items())}
task1_test_data = {new_key: task1_test_data[old_key] for new_key, (old_key, _) in enumerate(task1_test_data.items())}
task2_train_data = {new_key: task2_train_data[old_key] for new_key, (old_key, _) in enumerate(task2_train_data.items())}
task2_val_data = {new_key: task2_val_data[old_key] for new_key, (old_key, _) in enumerate(task2_val_data.items())}
task2_test_data = {new_key: task2_test_data[old_key] for new_key, (old_key, _) in enumerate(task2_test_data.items())}

# %%
class RNNModel(nn.Module):
    def __init__(self, embedding_dim, output_size):
        super(RNNModel, self).__init__()
        self.rnn = nn.RNN(embedding_dim, 32, num_layers=1, batch_first=True)
        # self.fc1 = nn.Linear(128, 64)
        self.fc1 = nn.Linear(32, output_size)

    def forward(self, x):
        # x = self.embedding_layer(x)
        out, _ = self.rnn(x)
        out = self.fc1(out)
        return out
    
class Task_data(Dataset):
    def __init__(self, data, bio_index, embedding_type):
        self.data = data
        self.length = len(self.data)
        self.bio_index =  bio_index
        self.embedding_type = embedding_type

    def __len__(self):
        return self.length

    def __getitem__(self, index):
        input_sequence = self.data[index]['text'].split(' ')
        sentence_embeddings = []
        if self.embedding_type == "glove":
            sentence_embeddings = [glove_embeddings.get(word, np.zeros(300, dtype = 'float32')) for word in input_sequence]
        elif self.embedding_type == "word2vec":
            sentence_embeddings = [word2vec_embeddings.get(word, np.zeros(300, dtype = 'float32')) for word in input_sequence]
        elif self.embedding_type == "fast_text":
            sentence_embeddings = [np.array(fast_text_embedding.get(word, np.zeros(300, dtype = 'float32')), dtype = 'float32') for word in input_sequence]

        sentence_embeddings = np.array(sentence_embeddings, dtype='float32')
        output_sequence = self.data[index]['labels']
        output_labels = [self.bio_index[word] for word in output_sequence]

        # output_labels = np.array(output_labels, dtype='float32')
        return torch.tensor(sentence_embeddings), torch.tensor(output_labels)

# %%
def train_model(task, embedding_type, model, optimizer, criterion, device,  num_epochs = 30, batch_size = 256):
    train_dataloader  = None
    val_dataloader  = None
    test_dataloader = None

    if task == 1:
        train_dataloader = DataLoader(Task_data(task1_train_data, bio_mapping_task1, embedding_type), batch_size=batch_size, shuffle=True)
        val_dataloader =  DataLoader(Task_data(task1_val_data, bio_mapping_task1, embedding_type), batch_size=batch_size, shuffle=True)
    elif task == 2:
        train_dataloader = DataLoader(Task_data(task2_train_data, bio_mapping_task2, embedding_type), batch_size=batch_size, shuffle=True)
        val_dataloader =  DataLoader(Task_data(task2_val_data, bio_mapping_task2, embedding_type), batch_size=batch_size, shuffle=True)


    train_losses = []
    val_losses = []
    train_f1_scores = []
    val_f1_scores = []

    # Training loop
    for epoch in range(num_epochs):
        model.train()  # Set the model to training mode
        total_train_loss = 0
        all_train_predictions = []
        all_train_targets = []

        for batch_idx, (inputs, targets) in enumerate(train_dataloader):
            inputs, targets = inputs.to(device), targets.to(device)
            optimizer.zero_grad()
            
            # Forward pass
            outputs = model(inputs)
            
            loss = 0
            # outputs[:, i, :].shape, 
            for i in range(outputs.size(1)):  # Iterate over time steps
                loss += criterion(outputs[:, i, :], targets[:, i])  
                # Apply CrossEntropyLoss at each time step
                # print(outputs[:, i, :].shape, targets[:, i].shape)
            
            loss.backward()
            optimizer.step()

            total_train_loss += loss.item()

            all_train_predictions.extend(outputs.argmax(dim=2).view(-1).cpu().numpy())
            all_train_targets.extend(targets.view(-1).cpu().numpy())


        avg_train_loss = total_train_loss / len(train_dataloader)
        train_losses.append(avg_train_loss)

        train_macro_f1 = f1_score(all_train_targets, all_train_predictions, average='macro')
        train_f1_scores.append(train_macro_f1)
        print(f"Epoch {epoch + 1}, Training Loss: {avg_train_loss}, Training Macro F1-Score: {train_macro_f1}")

        model.eval()  # Set the model to evaluation mode
        total_val_loss = 0
        all_val_predictions = []
        all_val_targets = []

        with torch.no_grad():
            for val_inputs, val_targets in val_dataloader:
                val_inputs, val_targets = val_inputs.to(device), val_targets.to(device)
                val_outputs = model(val_inputs)

                loss = 0
                for i in range(val_outputs.size(1)):  # Iterate over time steps
                    loss += criterion(val_outputs[:, i, :], val_targets[:, i])  

                total_val_loss += loss.item()

                all_val_predictions.extend(val_outputs.argmax(dim=2).view(-1).cpu().numpy())
                all_val_targets.extend(val_targets.view(-1).cpu().numpy())

            avg_val_loss = total_val_loss / len(val_dataloader)
            val_losses.append(avg_val_loss)

            val_macro_f1 = f1_score(all_val_targets, all_val_predictions, average='macro')
            val_f1_scores.append(val_macro_f1)
        print(f"Epoch {epoch + 1},  Validation Loss: {avg_val_loss}, Validation Macro F1-Score: {val_macro_f1}")
    plot_results(train_losses, val_losses, train_f1_scores, val_f1_scores)

    return train_losses, train_f1_scores, val_losses, val_f1_scores

def plot_results(train_losses, val_losses, train_f1_scores, val_f1_scores):
    epochs = range(1, len(train_losses) + 1)

    plt.figure(figsize=(12, 5))

    # Plotting Losses
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label='Training Loss')
    plt.plot(epochs, val_losses, label='Validation Loss')
    plt.title('Training and Validation Losses')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    # Plotting Macro F1-Scores
    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_f1_scores, label='Training Macro F1-Score')
    plt.plot(epochs, val_f1_scores, label='Validation Macro F1-Score')
    plt.title('Training and Validation Macro F1-Scores')
    plt.xlabel('Epochs')
    plt.ylabel('Macro F1-Score')
    plt.legend()

    plt.tight_layout()
    plt.show()

def plot_test_results(test_loss, test_macro_f1):
    plt.figure(figsize=(6, 6))
    labels = ['Test Loss', 'Test Macro F1-Score']
    values = [test_loss, test_macro_f1]

    plt.bar(labels, values, color=['blue', 'green'])
    plt.title('Test Results')
    plt.ylabel('Values')
    plt.show()

def test_model(task, embedding_type, model, criterion, device, batch_size = 1):
    test_dataloader = None
    if task == 1:
        test_dataloader =  DataLoader(Task_data(task1_test_data, bio_mapping_task1, embedding_type), batch_size=batch_size, shuffle=False)

    elif task == 2:
        test_dataloader =  DataLoader(Task_data(task2_test_data, bio_mapping_task2, embedding_type), batch_size=batch_size, shuffle=False)

    total_test_loss = 0
    all_test_predictions = []
    all_test_targets = []

    with torch.no_grad():
        for test_inputs, test_targets in test_dataloader:
            test_inputs, test_targets = test_inputs.to(device), test_targets.to(device)
            test_outputs = model(test_inputs)

            loss = 0
            for i in range(test_outputs.size(1)):  # Iterate over time steps
                loss += criterion(test_outputs[:, i, :], test_targets[:, i])  

            total_test_loss += loss.item()

            all_test_predictions.extend(test_outputs.argmax(dim=2).view(-1).cpu().numpy())
            all_test_targets.extend(test_targets.view(-1).cpu().numpy())

        avg_test_loss = total_test_loss / len(test_dataloader)
        test_macro_f1 = f1_score(all_test_targets, all_test_predictions, average='macro')
    print(f'Test Loss: {avg_test_loss}, Test Macro F1-Score: {test_macro_f1}')

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = RNNModel(300, 27).to(device) 
optimizer = optim.Adam(model.parameters(), lr=0.005)
criterion = nn.CrossEntropyLoss()

train_losses, train_f1_scores, val_losses, val_f1_scores =  train_model(task = 1, embedding_type = "glove", model = model, optimizer=optimizer,criterion=criterion, device=device, batch_size=128)
test_model(task = 1, embedding_type = "glove", model = model, criterion=criterion, device=device)

torch.save(model, 'trained_models/t1_rnn_glove.pt')
# Out:
# Epoch 1, Training Loss: 57.16585356290223, Training Macro F1-Score: 0.0456703486008143
# Epoch 1,  Validation Loss: 22.77906747297807, Validation Macro F1-Score: 0.05022477513703696
# Epoch 2, Training Loss: 19.502062344160237, Training Macro F1-Score: 0.0862207692122381
# Epoch 2,  Validation Loss: 17.705020037564363, Validation Macro F1-Score: 0.14107974165130047
# Epoch 3, Training Loss: 16.112845405203398, Training Macro F1-Score: 0.18430434818395827
# Epoch 3,  Validation Loss: 15.146432269703258, Validation Macro F1-Score: 0.2434795894340727
# Epoch 4, Training Loss: 14.119340505756316, Training Macro F1-Score: 0.2646010990350186
# Epoch 4,  Validation Loss: 13.639008522033691, Validation Macro F1-Score: 0.28605368851268154
# Epoch 5, Training Loss: 12.80406915946085, Training Macro F1-Score: 0.29997433464036827
# Epoch 5,  Validation Loss: 12.642548301003195, Validation Macro F1-Score: 0.32089812285829794
# Epoch 6, Training Loss: 11.820963499975987, Training Macro F1-Score: 0.3280695685600872
# Epoch 6,  Validation Loss: 11.798466422341086, Validation Macro F1-Score: 0.33806832435660067
# Epoch 7, Training Loss: 11.0812059934022, Training Macro F1-Score: 0.34523948383643366
# Epoch 7,  Validation Loss: 11.316367842934348, Validation Macro F1-Score: 0.3486124308781546
# Epoch 8, Training Loss: 10.521248379691702, Training Macro F1-Score: 0.3611933797857005
# Epoch 8,  Validation Loss: 10.984901948408647, Validation Macro F1-Score: 0.3559918305660996
# Epoch 9, Training Loss: 10.089247328336121, Training Macro F1-Score: 0.37382804591445074
# Epoch 9,  Validation Loss: 10.645305460149592, Validation Macro F1-Score: 0.36732257895287046
# Epoch 10, Training Loss: 9.737156821078942, Training Macro F1-Score: 0.38625337895821826
# Epoch 10,  Validation Loss: 10.57600246776234, Validation Macro F1-Score: 0.36835345332711633
# Epoch 11, Training Loss: 9.436758283708917, Training Macro F1-Score: 0.3962561516901765
# Epoch 11,  Validation Loss: 10.344394250349565, Validation Macro F1-Score: 0.385068183557399
# Epoch 12, Training Loss: 9.180881336087086, Training Macro F1-Score: 0.4052619557284025
# Epoch 12,  Validation Loss: 10.124521385539662, Validation Macro F1-Score: 0.39059689407006065
# Epoch 13, Training Loss: 8.945600837957663, Training Macro F1-Score: 0.4142480203183305
# Epoch 13,  Validation Loss: 9.992793256586248, Validation Macro F1-Score: 0.39663285383601415
# Epoch 14, Training Loss: 8.723406901125047, Training Macro F1-Score: 0.41892936098304473
# Epoch 14,  Validation Loss: 9.993579084222967, Validation Macro F1-Score: 0.3991690415487081
# Epoch 15, Training Loss: 8.574754902573883, Training Macro F1-Score: 0.42292815807234585
# Epoch 15,  Validation Loss: 9.788536418568004, Validation Macro F1-Score: 0.40113428860194805
# Epoch 16, Training Loss: 8.455113911237873, Training Macro F1-Score: 0.4266381498948891
# Epoch 16,  Validation Loss: 9.703542015769266, Validation Macro F1-Score: 0.40334253843144346
# Epoch 17, Training Loss: 8.268714506118023, Training Macro F1-Score: 0.43257864382176797
# Epoch 17,  Validation Loss: 9.72919784892689, Validation Macro F1-Score: 0.404180709571025
# Epoch 18, Training Loss: 8.153426881696356, Training Macro F1-Score: 0.4358976913130502
# Epoch 18,  Validation Loss: 9.671254114671187, Validation Macro F1-Score: 0.4083117177716837
# Epoch 19, Training Loss: 7.985353532384654, Training Macro F1-Score: 0.44095312492351985
# Epoch 19,  Validation Loss: 9.648742459037088, Validation Macro F1-Score: 0.40906106169162193
# Epoch 20, Training Loss: 7.914514854306081, Training Macro F1-Score: 0.4416250839382528
# Epoch 20,  Validation Loss: 9.548836708068848, Validation Macro F1-Score: 0.4115315967910771
# Epoch 21, Training Loss: 7.802683126730997, Training Macro F1-Score: 0.44611946235807665
# Epoch 21,  Validation Loss: 9.632830012928356, Validation Macro F1-Score: 0.41348141925244913
# Epoch 22, Training Loss: 7.741153779577036, Training Macro F1-Score: 0.44639632826831993
# Epoch 22,  Validation Loss: 9.679947159507059, Validation Macro F1-Score: 0.4126421527808322
# Epoch 23, Training Loss: 7.631244276390701, Training Macro F1-Score: 0.45081761740452253
# Epoch 23,  Validation Loss: 9.628252506256104, Validation Macro F1-Score: 0.41902057541938553
# Epoch 24, Training Loss: 7.574218218443824, Training Macro F1-Score: 0.4544644373151992
# Epoch 24,  Validation Loss: 9.627889199690385, Validation Macro F1-Score: 0.41672784367002214
# Epoch 25, Training Loss: 7.518120734418025, Training Macro F1-Score: 0.45560687295307706
# Epoch 25,  Validation Loss: 9.789920936931264, Validation Macro F1-Score: 0.41639559998265907
# Epoch 26, Training Loss: 7.50213731703211, Training Macro F1-Score: 0.4552390267687664
# Epoch 26,  Validation Loss: 9.567303744229404, Validation Macro F1-Score: 0.418261647702089
# Epoch 27, Training Loss: 7.353999067525395, Training Macro F1-Score: 0.4595984852263716
# Epoch 27,  Validation Loss: 9.791320844130082, Validation Macro F1-Score: 0.4225201155460293
# Epoch 28, Training Loss: 7.287810528864626, Training Macro F1-Score: 0.4656450228191858
# Epoch 28,  Validation Loss: 9.616729129444469, Validation Macro F1-Score: 0.42301434670581867
# Epoch 29, Training Loss: 7.246485178587867, Training Macro F1-Score: 0.4655943861485222
# Epoch 29,  Validation Loss: 9.777516798539596, Validation Macro F1-Score: 0.41788587227930946
# Epoch 30, Training Loss: 7.163545858664591, Training Macro F1-Score: 0.4692858257192314
# Epoch 30,  Validation Loss: 9.626052336259322, Validation Macro F1-Score: 0.4201430647520797
# Test Loss: 10.376716428062391, Test Macro F1-Score: 0.41710771184468665

# %%
model = RNNModel(300, 27).to(device) 
optimizer = optim.Adam(model.parameters(), lr=0.005)
criterion = nn.CrossEntropyLoss()
train_losses, train_f1_scores, val_losses, val_f1_scores =  train_model(task = 1, embedding_type = "word2vec", model = model, optimizer=optimizer, criterion=criterion, device=device, batch_size=128)
test_model(task = 1, embedding_type = "word2vec", model = model, criterion=criterion, device=device)

torch.save(model, 'trained_models/t1_rnn_word2vec.pt')
# Out:
# Epoch 1, Training Loss: 52.74507910306336, Training Macro F1-Score: 0.03677341962120611
# Epoch 1,  Validation Loss: 30.287410736083984, Validation Macro F1-Score: 0.037627502054553334
# Epoch 2, Training Loss: 25.09953655180384, Training Macro F1-Score: 0.049942125069886815
# Epoch 2,  Validation Loss: 21.378236423839223, Validation Macro F1-Score: 0.0729474732400142
# Epoch 3, Training Loss: 19.639859402765993, Training Macro F1-Score: 0.09939689097889745
# Epoch 3,  Validation Loss: 18.439334695989434, Validation Macro F1-Score: 0.11570780251467501
# Epoch 4, Training Loss: 17.131278929163198, Training Macro F1-Score: 0.14374865479595067
# Epoch 4,  Validation Loss: 16.293394088745117, Validation Macro F1-Score: 0.17919703760608116
# Epoch 5, Training Loss: 15.370274981514353, Training Macro F1-Score: 0.20990610325378178
# Epoch 5,  Validation Loss: 15.093748439442027, Validation Macro F1-Score: 0.23285726985823665
# Epoch 6, Training Loss: 14.320760492418634, Training Macro F1-Score: 0.24650708944234093
# Epoch 6,  Validation Loss: 14.20035813071511, Validation Macro F1-Score: 0.25712442147399855
# Epoch 7, Training Loss: 13.537112955187188, Training Macro F1-Score: 0.263985903259898
# Epoch 7,  Validation Loss: 13.616715344515713, Validation Macro F1-Score: 0.2703798426638242
# Epoch 8, Training Loss: 12.943515871391922, Training Macro F1-Score: 0.27456506541215464
# Epoch 8,  Validation Loss: 13.211699919267135, Validation Macro F1-Score: 0.2870254473164244
# Epoch 9, Training Loss: 12.522323170646292, Training Macro F1-Score: 0.29096980106253656
# Epoch 9,  Validation Loss: 12.94035850871693, Validation Macro F1-Score: 0.30507621810813546
# Epoch 10, Training Loss: 12.184651109038807, Training Macro F1-Score: 0.30731644530739427
# Epoch 10,  Validation Loss: 12.668905865062367, Validation Macro F1-Score: 0.30651665872754497
# Epoch 11, Training Loss: 11.82369694944288, Training Macro F1-Score: 0.3174382170878707
# Epoch 11,  Validation Loss: 12.432518352161754, Validation Macro F1-Score: 0.31955074978715164
# Epoch 12, Training Loss: 11.68433322281134, Training Macro F1-Score: 0.32526881485634296
# Epoch 12,  Validation Loss: 12.378164291381836, Validation Macro F1-Score: 0.31663289993659943
# Epoch 13, Training Loss: 11.38960295817891, Training Macro F1-Score: 0.33285927637495083
# Epoch 13,  Validation Loss: 12.072784077037465, Validation Macro F1-Score: 0.3319132506311575
# Epoch 14, Training Loss: 11.132263339933802, Training Macro F1-Score: 0.34040926075663697
# Epoch 14,  Validation Loss: 11.981456929987127, Validation Macro F1-Score: 0.33428762060650413
# Epoch 15, Training Loss: 10.925274989644034, Training Macro F1-Score: 0.3477963616729717
# Epoch 15,  Validation Loss: 12.073496211658824, Validation Macro F1-Score: 0.3281251941018079
# Epoch 16, Training Loss: 10.752408637375128, Training Macro F1-Score: 0.35277939004918035
# Epoch 16,  Validation Loss: 11.812881209633566, Validation Macro F1-Score: 0.34879586625423886
# Epoch 17, Training Loss: 10.574634677073995, Training Macro F1-Score: 0.3579380878162992
# Epoch 17,  Validation Loss: 11.661577658219771, Validation Macro F1-Score: 0.3498326051272797
# Epoch 18, Training Loss: 10.412326437528016, Training Macro F1-Score: 0.3627111645259353
# Epoch 18,  Validation Loss: 11.473122423345393, Validation Macro F1-Score: 0.3559019392548084
# Epoch 19, Training Loss: 10.317114814383086, Training Macro F1-Score: 0.3664410293686972
# Epoch 19,  Validation Loss: 11.492543307217685, Validation Macro F1-Score: 0.3548655591181752
# Epoch 20, Training Loss: 10.156794376060612, Training Macro F1-Score: 0.37196626272210304
# Epoch 20,  Validation Loss: 11.428164048628373, Validation Macro F1-Score: 0.35443093058995356
# Epoch 21, Training Loss: 10.112801067164687, Training Macro F1-Score: 0.3740789969458703
# Epoch 21,  Validation Loss: 11.31335717981512, Validation Macro F1-Score: 0.35961611807194477
# Epoch 22, Training Loss: 9.919313250995073, Training Macro F1-Score: 0.37840294054681256
# Epoch 22,  Validation Loss: 11.33220152421431, Validation Macro F1-Score: 0.3659295972262512
# Epoch 23, Training Loss: 9.795822354613758, Training Macro F1-Score: 0.3831206664053462
# Epoch 23,  Validation Loss: 11.191789713772861, Validation Macro F1-Score: 0.3660456107677261
# Epoch 24, Training Loss: 9.756241219942687, Training Macro F1-Score: 0.3863626363380627
# Epoch 24,  Validation Loss: 11.297569795088334, Validation Macro F1-Score: 0.3694903210212574
# Epoch 25, Training Loss: 9.60758367131968, Training Macro F1-Score: 0.39056325819133086
# Epoch 25,  Validation Loss: 11.176051053133877, Validation Macro F1-Score: 0.3666425857844543
# Epoch 26, Training Loss: 9.61219750857744, Training Macro F1-Score: 0.3937678877890044
# Epoch 26,  Validation Loss: 11.1509502584284, Validation Macro F1-Score: 0.3760118716249811
# Epoch 27, Training Loss: 9.537164336345235, Training Macro F1-Score: 0.39806799637346774
# Epoch 27,  Validation Loss: 11.284467697143555, Validation Macro F1-Score: 0.37053131054838895
# Epoch 28, Training Loss: 9.42715820718984, Training Macro F1-Score: 0.4044141342187703
# Epoch 28,  Validation Loss: 11.117469960992986, Validation Macro F1-Score: 0.37513506365834487
# Epoch 29, Training Loss: 9.34186237366473, Training Macro F1-Score: 0.40779384068073044
# Epoch 29,  Validation Loss: 11.215982177040793, Validation Macro F1-Score: 0.37843014485018645
# Epoch 30, Training Loss: 9.286276496824671, Training Macro F1-Score: 0.4156533859952643
# Epoch 30,  Validation Loss: 11.142937053333629, Validation Macro F1-Score: 0.3841346804306396
# Test Loss: 11.740047338547365, Test Macro F1-Score: 0.388980559944608

# %%
model = RNNModel(300, 27).to(device) 
optimizer = optim.Adam(model.parameters(), lr=0.005)
criterion = nn.CrossEntropyLoss()
train_losses, train_f1_scores, val_losses, val_f1_scores = train_model(task = 1, embedding_type = "fast_text", model = model, num_epochs = 20, optimizer=optimizer, criterion=criterion, batch_size=128, device=device)
test_model(task = 1, embedding_type = "fast_text", model = model, criterion=criterion, device=device)
torch.save(model, 'trained_models/t1_rnn_fast_text.pt')
# Out:
# Epoch 1, Training Loss: 57.82902692575924, Training Macro F1-Score: 0.03583907440716746
# Epoch 1,  Validation Loss: 32.20211844010787, Validation Macro F1-Score: 0.03588143807069892
# Epoch 2, Training Loss: 27.524473878203846, Training Macro F1-Score: 0.037500022712240795
# Epoch 2,  Validation Loss: 23.418439691716973, Validation Macro F1-Score: 0.03700030168017666
# Epoch 3, Training Loss: 21.290548824873127, Training Macro F1-Score: 0.04118646973235051
# Epoch 3,  Validation Loss: 20.297754981301047, Validation Macro F1-Score: 0.04837915852809668
# Epoch 4, Training Loss: 19.070439166710024, Training Macro F1-Score: 0.053485845398944125
# Epoch 4,  Validation Loss: 18.53115359219638, Validation Macro F1-Score: 0.054625411144996944
# Epoch 5, Training Loss: 17.490090901734398, Training Macro F1-Score: 0.06661805566541831
# Epoch 5,  Validation Loss: 17.071630651300605, Validation Macro F1-Score: 0.07298828171345927
# Epoch 6, Training Loss: 16.11527910388884, Training Macro F1-Score: 0.0904249942620215
# Epoch 6,  Validation Loss: 15.755985606800426, Validation Macro F1-Score: 0.10982912562625777
# Epoch 7, Training Loss: 14.94314781564181, Training Macro F1-Score: 0.12274393121350397
# Epoch 7,  Validation Loss: 14.732300758361816, Validation Macro F1-Score: 0.14058234934946623
# Epoch 8, Training Loss: 13.964976513972047, Training Macro F1-Score: 0.16375755888174334
# Epoch 8,  Validation Loss: 13.76434308832342, Validation Macro F1-Score: 0.18909544028024505
# Epoch 9, Training Loss: 13.120175205293249, Training Macro F1-Score: 0.20293840718811904
# Epoch 9,  Validation Loss: 13.02484503659335, Validation Macro F1-Score: 0.2172813056914384
# Epoch 10, Training Loss: 12.428103728372543, Training Macro F1-Score: 0.23057729919362788
# Epoch 10,  Validation Loss: 12.370936133644797, Validation Macro F1-Score: 0.24703639009656053
# Epoch 11, Training Loss: 11.890230491513112, Training Macro F1-Score: 0.25338475661688936
# Epoch 11,  Validation Loss: 11.825017842379483, Validation Macro F1-Score: 0.2585914860926239
# Epoch 12, Training Loss: 11.358665481942598, Training Macro F1-Score: 0.2766851587195038
# Epoch 12,  Validation Loss: 11.42392331903631, Validation Macro F1-Score: 0.28859371723590427
# Epoch 13, Training Loss: 10.911415475313781, Training Macro F1-Score: 0.3032904986400424
# Epoch 13,  Validation Loss: 10.912765589627353, Validation Macro F1-Score: 0.3188150891693315
# Epoch 14, Training Loss: 10.49198636852327, Training Macro F1-Score: 0.3250087975679503
# Epoch 14,  Validation Loss: 10.658610170537775, Validation Macro F1-Score: 0.3328274839781563
# Epoch 15, Training Loss: 10.093156564431112, Training Macro F1-Score: 0.34301583888302933
# Epoch 15,  Validation Loss: 10.225648273121227, Validation Macro F1-Score: 0.35160794210568214
# Epoch 16, Training Loss: 9.76074646340042, Training Macro F1-Score: 0.3562612568096615
# Epoch 16,  Validation Loss: 9.98914822665128, Validation Macro F1-Score: 0.3624290981745467
# Epoch 17, Training Loss: 9.460199387347112, Training Macro F1-Score: 0.3673045924174281
# Epoch 17,  Validation Loss: 9.738926974209873, Validation Macro F1-Score: 0.3726411773938723
# Epoch 18, Training Loss: 9.191966408588847, Training Macro F1-Score: 0.3749001472281175
# Epoch 18,  Validation Loss: 9.637366078116678, Validation Macro F1-Score: 0.3826777461332889
# Epoch 19, Training Loss: 9.027479898734171, Training Macro F1-Score: 0.3843684431928729
# Epoch 19,  Validation Loss: 9.329631805419922, Validation Macro F1-Score: 0.383971483173984
# Epoch 20, Training Loss: 8.803593729363113, Training Macro F1-Score: 0.3906533408270426
# Epoch 20,  Validation Loss: 9.063710689544678, Validation Macro F1-Score: 0.3889786275529526
# Test Loss: 9.752915718593716, Test Macro F1-Score: 0.3948508353035882

# %%
model = RNNModel(300, 3).to(device) 
optimizer = optim.Adam(model.parameters(), lr=0.005)
criterion = nn.CrossEntropyLoss()
train_losses, train_f1_scores, val_losses, val_f1_scores = train_model(task = 2, embedding_type = "fast_text", model = model, optimizer=optimizer, criterion=criterion, device=device, batch_size=256)

test_model(task = 2, embedding_type = "fast_text", model = model, criterion=criterion, device=device)
torch.save(model, 'trained_models/t2_rnn_fast_text.pt')
# Out:
# Epoch 1, Training Loss: 69.94040107727051, Training Macro F1-Score: 0.3291960995596706
# Epoch 1,  Validation Loss: 53.628936767578125, Validation Macro F1-Score: 0.329410039232941
# Epoch 2, Training Loss: 39.92569828033447, Training Macro F1-Score: 0.32919834423063704
# Epoch 2,  Validation Loss: 19.241409301757812, Validation Macro F1-Score: 0.329410039232941
# Epoch 3, Training Loss: 14.851779222488403, Training Macro F1-Score: 0.32919834423063704
# Epoch 3,  Validation Loss: 10.718486785888672, Validation Macro F1-Score: 0.329410039232941
# Epoch 4, Training Loss: 11.033921718597412, Training Macro F1-Score: 0.32919834423063704
# Epoch 4,  Validation Loss: 10.490034103393555, Validation Macro F1-Score: 0.329410039232941
# Epoch 5, Training Loss: 11.203392505645752, Training Macro F1-Score: 0.32919834423063704
# Epoch 5,  Validation Loss: 10.947227478027344, Validation Macro F1-Score: 0.329410039232941
# Epoch 6, Training Loss: 11.705947875976562, Training Macro F1-Score: 0.32919834423063704
# Epoch 6,  Validation Loss: 11.15550708770752, Validation Macro F1-Score: 0.329410039232941
# Epoch 7, Training Loss: 11.608068227767944, Training Macro F1-Score: 0.32919834423063704
# Epoch 7,  Validation Loss: 11.060785293579102, Validation Macro F1-Score: 0.329410039232941
# Epoch 8, Training Loss: 11.495382070541382, Training Macro F1-Score: 0.32919834423063704
# Epoch 8,  Validation Loss: 10.767975807189941, Validation Macro F1-Score: 0.329410039232941
# Epoch 9, Training Loss: 11.195927381515503, Training Macro F1-Score: 0.32919834423063704
# Epoch 9,  Validation Loss: 10.41067123413086, Validation Macro F1-Score: 0.329410039232941
# Epoch 10, Training Loss: 10.966060638427734, Training Macro F1-Score: 0.32919834423063704
# Epoch 10,  Validation Loss: 10.114850044250488, Validation Macro F1-Score: 0.329410039232941
# Epoch 11, Training Loss: 10.676137924194336, Training Macro F1-Score: 0.32919834423063704
# Epoch 11,  Validation Loss: 9.96004581451416, Validation Macro F1-Score: 0.33166376707888684
# Epoch 12, Training Loss: 10.381873846054077, Training Macro F1-Score: 0.33024195455524147
# Epoch 12,  Validation Loss: 9.892430305480957, Validation Macro F1-Score: 0.3614763072529537
# Epoch 13, Training Loss: 10.44409704208374, Training Macro F1-Score: 0.3559276373107532
# Epoch 13,  Validation Loss: 19.557903289794922, Validation Macro F1-Score: 0.4045409070179353
# Epoch 14, Training Loss: 12.32986569404602, Training Macro F1-Score: 0.387874891962844
# Epoch 14,  Validation Loss: 9.780529022216797, Validation Macro F1-Score: 0.3950985618618086
# Epoch 15, Training Loss: 10.275350093841553, Training Macro F1-Score: 0.36293482125787974
# Epoch 15,  Validation Loss: 9.753284454345703, Validation Macro F1-Score: 0.35339679418662096
# Epoch 16, Training Loss: 10.297786235809326, Training Macro F1-Score: 0.333869215038803
# Epoch 16,  Validation Loss: 9.729551315307617, Validation Macro F1-Score: 0.33612618074230677
# Epoch 17, Training Loss: 10.262179374694824, Training Macro F1-Score: 0.3307625457063677
# Epoch 17,  Validation Loss: 9.684325218200684, Validation Macro F1-Score: 0.33612618074230677
# Epoch 18, Training Loss: 10.329161882400513, Training Macro F1-Score: 0.3307625457063677
# Epoch 18,  Validation Loss: 9.604048728942871, Validation Macro F1-Score: 0.34487500239420754
# Epoch 19, Training Loss: 10.139990091323853, Training Macro F1-Score: 0.34249245585204774
# Epoch 19,  Validation Loss: 9.485421180725098, Validation Macro F1-Score: 0.37346897869210943
# Epoch 20, Training Loss: 10.023067235946655, Training Macro F1-Score: 0.35916930294161403
# Epoch 20,  Validation Loss: 9.339739799499512, Validation Macro F1-Score: 0.3883997792780926
# Epoch 21, Training Loss: 9.823244094848633, Training Macro F1-Score: 0.371226308395336
# Epoch 21,  Validation Loss: 9.165118217468262, Validation Macro F1-Score: 0.3953252320640432
# Epoch 22, Training Loss: 9.650030374526978, Training Macro F1-Score: 0.37854467216934595
# Epoch 22,  Validation Loss: 8.975776672363281, Validation Macro F1-Score: 0.4066707181209169
# Epoch 23, Training Loss: 9.696552991867065, Training Macro F1-Score: 0.38226395627272836
# Epoch 23,  Validation Loss: 8.667686462402344, Validation Macro F1-Score: 0.4001558012353936
# Epoch 24, Training Loss: 9.06006407737732, Training Macro F1-Score: 0.3846795536325714
# Epoch 24,  Validation Loss: 8.308723449707031, Validation Macro F1-Score: 0.40357976871279727
# Epoch 25, Training Loss: 8.52597188949585, Training Macro F1-Score: 0.38682942284182914
# Epoch 25,  Validation Loss: 7.813080310821533, Validation Macro F1-Score: 0.4066380133715377
# Epoch 26, Training Loss: 7.974385619163513, Training Macro F1-Score: 0.3924472368367465
# Epoch 26,  Validation Loss: 7.302219390869141, Validation Macro F1-Score: 0.4075947188424965
# Epoch 27, Training Loss: 7.41385555267334, Training Macro F1-Score: 0.3977345701804756
# Epoch 27,  Validation Loss: 6.9216718673706055, Validation Macro F1-Score: 0.4143512503029619
# Epoch 28, Training Loss: 7.031498193740845, Training Macro F1-Score: 0.39853042040298375
# Epoch 28,  Validation Loss: 6.595829486846924, Validation Macro F1-Score: 0.41491457373925184
# Epoch 29, Training Loss: 6.7060792446136475, Training Macro F1-Score: 0.39832920322841536
# Epoch 29,  Validation Loss: 6.353378772735596, Validation Macro F1-Score: 0.4137951574867338
# Epoch 30, Training Loss: 6.4330445528030396, Training Macro F1-Score: 0.3958485637159768
# Epoch 30,  Validation Loss: 6.1540422439575195, Validation Macro F1-Score: 0.41141518835754426
# Test Loss: 6.40417336618028, Test Macro F1-Score: 0.38904428761369086

# %%
model = RNNModel(300, 3).to(device) 
optimizer = optim.Adam(model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()
train_losses, train_f1_scores, val_losses, val_f1_scores = train_model(task = 2, embedding_type = "glove", model = model, optimizer=optimizer, criterion=criterion, device=device)
test_model(task = 2, embedding_type = "glove", model = model, criterion=criterion, device=device)
torch.save(model, 'trained_models/t2_rnn_glove.pt')
# Out:
# Epoch 1, Training Loss: 82.48182106018066, Training Macro F1-Score: 0.3719446078282373
# Epoch 1,  Validation Loss: 77.20552062988281, Validation Macro F1-Score: 0.4176470249312116
# Epoch 2, Training Loss: 74.20370674133301, Training Macro F1-Score: 0.4128271596028665
# Epoch 2,  Validation Loss: 68.86603546142578, Validation Macro F1-Score: 0.419388660854668
# Epoch 3, Training Loss: 65.77315902709961, Training Macro F1-Score: 0.39288719616549095
# Epoch 3,  Validation Loss: 60.04463577270508, Validation Macro F1-Score: 0.36219622401616564
# Epoch 4, Training Loss: 56.62948417663574, Training Macro F1-Score: 0.3529767943932513
# Epoch 4,  Validation Loss: 50.46409606933594, Validation Macro F1-Score: 0.34642064036587333
# Epoch 5, Training Loss: 46.85143566131592, Training Macro F1-Score: 0.3435216770937854
# Epoch 5,  Validation Loss: 40.36367416381836, Validation Macro F1-Score: 0.3424747384961233
# Epoch 6, Training Loss: 36.89949989318848, Training Macro F1-Score: 0.3387583791121038
# Epoch 6,  Validation Loss: 30.807918548583984, Validation Macro F1-Score: 0.34044695040523965
# Epoch 7, Training Loss: 27.98770523071289, Training Macro F1-Score: 0.33733860590551884
# Epoch 7,  Validation Loss: 23.167375564575195, Validation Macro F1-Score: 0.33834422777793055
# Epoch 8, Training Loss: 21.273661136627197, Training Macro F1-Score: 0.3363916924728289
# Epoch 8,  Validation Loss: 17.92665672302246, Validation Macro F1-Score: 0.33834422777793055
# Epoch 9, Training Loss: 16.884814739227295, Training Macro F1-Score: 0.335889577306961
# Epoch 9,  Validation Loss: 14.625473022460938, Validation Macro F1-Score: 0.33834422777793055
# Epoch 10, Training Loss: 14.111417770385742, Training Macro F1-Score: 0.33639945573608415
# Epoch 10,  Validation Loss: 12.58906078338623, Validation Macro F1-Score: 0.340538597436091
# Epoch 11, Training Loss: 12.395241975784302, Training Macro F1-Score: 0.33741687310405094
# Epoch 11,  Validation Loss: 11.301602363586426, Validation Macro F1-Score: 0.34052953600975044
# Epoch 12, Training Loss: 11.325407028198242, Training Macro F1-Score: 0.3394311700780044
# Epoch 12,  Validation Loss: 10.44192886352539, Validation Macro F1-Score: 0.3448150646723531
# Epoch 13, Training Loss: 10.606051206588745, Training Macro F1-Score: 0.34343716595922097
# Epoch 13,  Validation Loss: 9.818426132202148, Validation Macro F1-Score: 0.3490170114715123
# Epoch 14, Training Loss: 10.061574459075928, Training Macro F1-Score: 0.3448854853748546
# Epoch 14,  Validation Loss: 9.321480751037598, Validation Macro F1-Score: 0.3593280400756722
# Epoch 15, Training Loss: 9.495494842529297, Training Macro F1-Score: 0.35739958354967505
# Epoch 15,  Validation Loss: 8.886834144592285, Validation Macro F1-Score: 0.3711184888509629
# Epoch 16, Training Loss: 9.110211610794067, Training Macro F1-Score: 0.37151800996715584
# Epoch 16,  Validation Loss: 8.486432075500488, Validation Macro F1-Score: 0.3875470992716983
# Epoch 17, Training Loss: 8.707592248916626, Training Macro F1-Score: 0.3765608991120335
# Epoch 17,  Validation Loss: 8.113504409790039, Validation Macro F1-Score: 0.4008480223697089
# Epoch 18, Training Loss: 8.406909465789795, Training Macro F1-Score: 0.39125126334064103
# Epoch 18,  Validation Loss: 7.775306701660156, Validation Macro F1-Score: 0.4162926773563312
# Epoch 19, Training Loss: 8.022565484046936, Training Macro F1-Score: 0.4094018731329794
# Epoch 19,  Validation Loss: 7.482909202575684, Validation Macro F1-Score: 0.43691034120992006
# Epoch 20, Training Loss: 7.698559522628784, Training Macro F1-Score: 0.43307020070465146
# Epoch 20,  Validation Loss: 7.240840911865234, Validation Macro F1-Score: 0.4536723389530673
# Epoch 21, Training Loss: 7.398481249809265, Training Macro F1-Score: 0.4449334709422461
# Epoch 21,  Validation Loss: 7.024077415466309, Validation Macro F1-Score: 0.4596258873587146
# Epoch 22, Training Loss: 7.208842992782593, Training Macro F1-Score: 0.45737691936613567
# Epoch 22,  Validation Loss: 6.813218116760254, Validation Macro F1-Score: 0.4623378309469827
# Epoch 23, Training Loss: 6.985637426376343, Training Macro F1-Score: 0.4672519449965729
# Epoch 23,  Validation Loss: 6.611670970916748, Validation Macro F1-Score: 0.4582473706395207
# Epoch 24, Training Loss: 6.777308106422424, Training Macro F1-Score: 0.46930036059867214
# Epoch 24,  Validation Loss: 6.420717239379883, Validation Macro F1-Score: 0.4628119105913065
# Epoch 25, Training Loss: 6.635554313659668, Training Macro F1-Score: 0.4704309964503171
# Epoch 25,  Validation Loss: 6.247138500213623, Validation Macro F1-Score: 0.46798938097872833
# Epoch 26, Training Loss: 6.386735200881958, Training Macro F1-Score: 0.4739034619127616
# Epoch 26,  Validation Loss: 6.088099002838135, Validation Macro F1-Score: 0.469134311978429
# Epoch 27, Training Loss: 6.2376216650009155, Training Macro F1-Score: 0.4765543145481899
# Epoch 27,  Validation Loss: 5.944088459014893, Validation Macro F1-Score: 0.47182945431842943
# Epoch 28, Training Loss: 6.07919979095459, Training Macro F1-Score: 0.47551016064172935
# Epoch 28,  Validation Loss: 5.813697338104248, Validation Macro F1-Score: 0.47428417754007673
# Epoch 29, Training Loss: 6.004179239273071, Training Macro F1-Score: 0.4796007054353111
# Epoch 29,  Validation Loss: 5.694150447845459, Validation Macro F1-Score: 0.4725479932834573
# Epoch 30, Training Loss: 5.808858275413513, Training Macro F1-Score: 0.4827130409415905
# Epoch 30,  Validation Loss: 5.584487438201904, Validation Macro F1-Score: 0.4830739724785864
# Test Loss: 5.92492855176693, Test Macro F1-Score: 0.49614033381035155

# %%
model = RNNModel(300, 3).to(device) 
optimizer = optim.Adam(model.parameters(), lr=0.001)

criterion = nn.CrossEntropyLoss()
train_losses, train_f1_scores, val_losses, val_f1_scores = train_model(task = 2, embedding_type = "word2vec", model = model, num_epochs=30,optimizer=optimizer, criterion=criterion, device=device)
test_model(task = 2, embedding_type = "word2vec", model = model, criterion=criterion, device=device)
torch.save(model, 'trained_models/t2_rnn_word2vec.pt')
# Out:
# Epoch 1, Training Loss: 75.83904838562012, Training Macro F1-Score: 0.4406795462736719
# Epoch 1,  Validation Loss: 70.67669677734375, Validation Macro F1-Score: 0.38693108797149406
# Epoch 2, Training Loss: 67.35482788085938, Training Macro F1-Score: 0.36875054008918795
# Epoch 2,  Validation Loss: 61.552249908447266, Validation Macro F1-Score: 0.3468176299011152
# Epoch 3, Training Loss: 57.76545715332031, Training Macro F1-Score: 0.33990367762167684
# Epoch 3,  Validation Loss: 50.95766067504883, Validation Macro F1-Score: 0.32938221354381525
# Epoch 4, Training Loss: 46.71074962615967, Training Macro F1-Score: 0.3302389005136298
# Epoch 4,  Validation Loss: 39.25392150878906, Validation Macro F1-Score: 0.329400764513379
# Epoch 5, Training Loss: 35.134583950042725, Training Macro F1-Score: 0.32919834423063704
# Epoch 5,  Validation Loss: 28.319177627563477, Validation Macro F1-Score: 0.329410039232941
# Epoch 6, Training Loss: 25.265446662902832, Training Macro F1-Score: 0.32919834423063704
# Epoch 6,  Validation Loss: 20.25539779663086, Validation Macro F1-Score: 0.329410039232941
# Epoch 7, Training Loss: 18.543833255767822, Training Macro F1-Score: 0.32919834423063704
# Epoch 7,  Validation Loss: 15.33310317993164, Validation Macro F1-Score: 0.329410039232941
# Epoch 8, Training Loss: 14.544437170028687, Training Macro F1-Score: 0.32919834423063704
# Epoch 8,  Validation Loss: 12.586301803588867, Validation Macro F1-Score: 0.329410039232941
# Epoch 9, Training Loss: 12.365949392318726, Training Macro F1-Score: 0.32919834423063704
# Epoch 9,  Validation Loss: 11.081300735473633, Validation Macro F1-Score: 0.329410039232941
# Epoch 10, Training Loss: 11.047717332839966, Training Macro F1-Score: 0.32972055469466516
# Epoch 10,  Validation Loss: 10.231494903564453, Validation Macro F1-Score: 0.329410039232941
# Epoch 11, Training Loss: 10.387006044387817, Training Macro F1-Score: 0.33231948575476783
# Epoch 11,  Validation Loss: 9.711722373962402, Validation Macro F1-Score: 0.3339024305310741
# Epoch 12, Training Loss: 9.93369722366333, Training Macro F1-Score: 0.3399446627591785
# Epoch 12,  Validation Loss: 9.351949691772461, Validation Macro F1-Score: 0.34052953600975044
# Epoch 13, Training Loss: 9.807596921920776, Training Macro F1-Score: 0.34492339504401026
# Epoch 13,  Validation Loss: 9.066100120544434, Validation Macro F1-Score: 0.3614763072529537
# Epoch 14, Training Loss: 9.497053384780884, Training Macro F1-Score: 0.3568958405211153
# Epoch 14,  Validation Loss: 8.809657096862793, Validation Macro F1-Score: 0.36727192302061235
# Epoch 15, Training Loss: 9.232905387878418, Training Macro F1-Score: 0.3598833757937226
# Epoch 15,  Validation Loss: 8.566230773925781, Validation Macro F1-Score: 0.3709435234656167
# Epoch 16, Training Loss: 9.064175605773926, Training Macro F1-Score: 0.37079757247985357
# Epoch 16,  Validation Loss: 8.327743530273438, Validation Macro F1-Score: 0.387840947582446
# Epoch 17, Training Loss: 8.768522500991821, Training Macro F1-Score: 0.3786262957059947
# Epoch 17,  Validation Loss: 8.095266342163086, Validation Macro F1-Score: 0.39612414561454834
# Epoch 18, Training Loss: 8.672502756118774, Training Macro F1-Score: 0.38954886266006755
# Epoch 18,  Validation Loss: 7.873219013214111, Validation Macro F1-Score: 0.40734928607436044
# Epoch 19, Training Loss: 8.364386320114136, Training Macro F1-Score: 0.39801668492496717
# Epoch 19,  Validation Loss: 7.661104202270508, Validation Macro F1-Score: 0.41285436186462454
# Epoch 20, Training Loss: 8.20803952217102, Training Macro F1-Score: 0.40747533042647716
# Epoch 20,  Validation Loss: 7.466744899749756, Validation Macro F1-Score: 0.43137014717736927
# Epoch 21, Training Loss: 8.036098599433899, Training Macro F1-Score: 0.4245016352535939
# Epoch 21,  Validation Loss: 7.285876750946045, Validation Macro F1-Score: 0.444795024398606
# Epoch 22, Training Loss: 7.845169305801392, Training Macro F1-Score: 0.4368768778279087
# Epoch 22,  Validation Loss: 7.121814250946045, Validation Macro F1-Score: 0.45127714609798336
# Epoch 23, Training Loss: 7.658057808876038, Training Macro F1-Score: 0.4482836476740332
# Epoch 23,  Validation Loss: 6.970523834228516, Validation Macro F1-Score: 0.4604834754594643
# Epoch 24, Training Loss: 7.487610340118408, Training Macro F1-Score: 0.45848556101759047
# Epoch 24,  Validation Loss: 6.829145431518555, Validation Macro F1-Score: 0.4703412782417325
# Epoch 25, Training Loss: 7.357688546180725, Training Macro F1-Score: 0.4676793528203656
# Epoch 25,  Validation Loss: 6.695139408111572, Validation Macro F1-Score: 0.4793148320481286
# Epoch 26, Training Loss: 7.222723007202148, Training Macro F1-Score: 0.47904758807151726
# Epoch 26,  Validation Loss: 6.5674052238464355, Validation Macro F1-Score: 0.4863706222217668
# Epoch 27, Training Loss: 7.031238913536072, Training Macro F1-Score: 0.4816115311856645
# Epoch 27,  Validation Loss: 6.446087837219238, Validation Macro F1-Score: 0.4888328549700234
# Epoch 28, Training Loss: 6.876919507980347, Training Macro F1-Score: 0.4814389932498239
# Epoch 28,  Validation Loss: 6.3303632736206055, Validation Macro F1-Score: 0.4858713773892643
# Epoch 29, Training Loss: 6.783653378486633, Training Macro F1-Score: 0.4812497813962821
# Epoch 29,  Validation Loss: 6.218911170959473, Validation Macro F1-Score: 0.48661448471291885
# Epoch 30, Training Loss: 6.635135173797607, Training Macro F1-Score: 0.4817041565537676
# Epoch 30,  Validation Loss: 6.111371040344238, Validation Macro F1-Score: 0.4896039298690711
# Test Loss: 6.679583282732382, Test Macro F1-Score: 0.49412518400934524
